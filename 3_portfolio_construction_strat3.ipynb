# %%
# Importation of our own tools
import portfolio_functions as pf
import tickers_select as tckrs
# %load_ext autoreload
# %autoreload 2

# Data manipulation
import pandas as pd
import numpy as np

# Plotting
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()
sns.set(rc={"figure.figsize":(12, 8)},style="whitegrid")
plt.rcParams['font.family'] = 'serif'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 1. Formating Datas

# %%
# Importation of the prices
prices = pd.read_csv("datas/adjusted_daily_prices.csv", index_col=0, parse_dates=True)
# Importation of the selected tickers
tickers = tckrs.tickers3

prices_msci = prices
prices = prices[tickers]

# Plotting of the DataFrame
prices.head()
# Out:
#                  ASML      MC.PA        NVS        SAP     CFR.SW       ABB  \
# Date
# 2005-01-03  13.137519  56.599998  33.440810  32.694855  16.481361  4.201927
# 2005-01-04  12.883060  56.299999  33.091171  31.870259  16.288680  4.216240
# 2005-01-05  12.698572  55.450001  32.967802  31.784551  15.938569  4.262036
# 2005-01-06  12.587189  55.650002  33.026834  32.465939  16.181642  4.316150
# 2005-01-07  12.592865  56.049999  32.965059  33.198153  16.110859  4.310554
#
#                RMS.PA     KER.PA      RI.PA    ISP.MI  ...      LI.PA  BOL.PA  \
# Date                                                   ...
# 2005-01-03  49.166664  68.918274  53.383133  3.290334  ...  21.145081   0.595
# 2005-01-04  48.833332  68.964745  53.524609  3.299682  ...  20.494463   0.595
# 2005-01-05  48.299999  68.128250  53.854713  3.327724  ...  20.169153   0.590
# 2005-01-06  48.366665  68.453552  53.666080  3.402505  ...  20.169153   0.590
# 2005-01-07  47.933334  69.150635  53.854713  3.402505  ...  20.494463   0.588
#
#             DIE.BR     GFC.PA  SECU-B.ST  IDVA.SG      FR.PA      LBGUF  \
# Date
# 2005-01-03   13.85  72.335732  12.785884     12.0  10.643333  31.290252
# 2005-01-04   13.96  70.773827  12.710694     12.0  10.683333  31.733229
# 2005-01-05   13.90  70.529778  12.515922     12.0  10.503333  31.737864
# 2005-01-06   13.86  69.797638  12.366672     12.0  10.456666  31.971365
# 2005-01-07   14.13  71.310730  12.395002     12.0  10.450000  32.270195
#
#                COV.PA      MF.PA
# Date
# 2005-01-03  60.918514  54.200001
# 2005-01-04  60.918514  53.849998
# 2005-01-05  60.918514  54.150002
# 2005-01-06  60.820255  54.400002
# 2005-01-07  60.918514  54.299999
#
# [5 rows x 56 columns]

# %%
prices_msci.head()
# Out:
#                 NSRGY       ASML     ROG.SW      MC.PA       NVO        NVS  \
# Date
# 2005-01-03  19.406073  13.137519  85.102253  56.599998  3.934667  33.440810
# 2005-01-04  19.304356  12.883060  84.902008  56.299999  3.858613  33.091171
# 2005-01-05  19.382477  12.698572  84.532489  55.450001  3.821526  32.967802
# 2005-01-06  19.403709  12.587189  84.744668  55.650002  3.949011  33.026834
# 2005-01-07  19.447257  12.592865  84.661544  56.049999  4.004297  32.965059
#
#                   VTI        SAP     SIE.DE        SNY  ...      MF.PA  \
# Date                                                    ...
# 2005-01-03  43.504051  32.694855  61.000427  29.547120  ...  54.200001
# 2005-01-04  43.532679  31.870259  60.661266  29.513681  ...  53.849998
# 2005-01-05  43.237832  31.784551  59.779449  29.088776  ...  54.150002
# 2005-01-06  43.764542  32.465939  60.341488  28.824900  ...  54.400002
# 2005-01-07  44.031957  33.198153  60.651573  29.025414  ...  54.299999
#
#             TIT.MI     ADE.OL     KGX.DE   SALM.OL        UPS  ROCK-B.CO  \
# Date
# 2005-01-03    3.06  10.817800  23.540001  4.735596  63.103147  37.261734
# 2005-01-04    3.06  10.759532  23.540001  4.710088  63.183368  37.928716
# 2005-01-05    3.03  10.776711  23.540001  4.717609  63.064586  37.570233
# 2005-01-06    3.06  10.773975  23.540001  4.716411  63.460296  37.365088
# 2005-01-07    3.06  10.819771  23.540001  4.736458  63.930943  37.633902
#
#             VSBY.CN    PROX.BR  UN01.DE
# Date
# 2005-01-03     0.51  32.770000     10.3
# 2005-01-04     0.51  32.930000     10.3
# 2005-01-05     0.51  32.450001     10.3
# 2005-01-06     0.51  32.160000     10.3
# 2005-01-07     0.51  32.160000     10.3
#
# [5 rows x 313 columns]

# %%
# Calculation of the returns and we remove the NaN (at the beginning of the DataFrame and at the end)
rends = prices.pct_change().dropna()
rends_msci = prices_msci.pct_change()

# %%
rends_msci.isna().sum().sort_values(ascending=False)
# Out:
# CNH=X      4639
# CBK.DE     4639
# SW.PA      4639
# SEK=F      4639
# NSRGY         1
#            ...
# SGSN.SW       1
# SY1.DE        1
# KRZ.IR        1
# CABK.MC       1
# UN01.DE       1
# Length: 313, dtype: int64

# %%
rends_msci.drop(["CNH=X","CBK.DE","SW.PA","SEK=F"],axis=1,inplace=True)

# %%
# Printing of the returns
rends.head()
# Out:
#                 ASML     MC.PA       NVS       SAP    CFR.SW       ABB  \
# Date
# 2005-01-04 -0.019369 -0.005300 -0.010455 -0.025221 -0.011691  0.003406
# 2005-01-05 -0.014320 -0.015098 -0.003728 -0.002689 -0.021494  0.010862
# 2005-01-06 -0.008771  0.003607  0.001791  0.021438  0.015251  0.012697
# 2005-01-07  0.000451  0.007188 -0.001870  0.022553 -0.004374 -0.001297
# 2005-01-10  0.013300 -0.006244 -0.006846 -0.004195  0.006278  0.008651
#
#               RMS.PA    KER.PA     RI.PA    ISP.MI  ...     LI.PA    BOL.PA  \
# Date                                                ...
# 2005-01-04 -0.006780  0.000674  0.002650  0.002841  ... -0.030769  0.000000
# 2005-01-05 -0.010921 -0.012129  0.006167  0.008498  ... -0.015873 -0.008403
# 2005-01-06  0.001380  0.004775 -0.003503  0.022472  ...  0.000000  0.000000
# 2005-01-07 -0.008959  0.010183  0.003515  0.000000  ...  0.016129 -0.003390
# 2005-01-10  0.019471 -0.002016 -0.011384  0.000000  ...  0.000000  0.002551
#
#               DIE.BR    GFC.PA  SECU-B.ST  IDVA.SG     FR.PA     LBGUF  \
# Date
# 2005-01-04  0.007942 -0.021592  -0.005881      0.0  0.003758  0.014157
# 2005-01-05 -0.004298 -0.003448  -0.015323      0.0 -0.016849  0.000146
# 2005-01-06 -0.002878 -0.010381  -0.011925      0.0 -0.004443  0.007357
# 2005-01-07  0.019481  0.021678   0.002291      0.0 -0.000638  0.009347
# 2005-01-10 -0.006369  0.004107   0.008505      0.0  0.015311 -0.003736
#
#               COV.PA     MF.PA
# Date
# 2005-01-04  0.000000 -0.006458
# 2005-01-05  0.000000  0.005571
# 2005-01-06 -0.001613  0.004617
# 2005-01-07  0.001616 -0.001838
# 2005-01-10  0.004839  0.014733
#
# [5 rows x 56 columns]

# %%
# Printing of the returns
rends.tail()
# Out:
#                 ASML     MC.PA       NVS       SAP    CFR.SW       ABB  \
# Date
# 2022-11-25  0.000781 -0.002848  0.000781  0.000781 -0.012240  0.000781
# 2022-11-28 -0.010505 -0.002142  0.003570 -0.020130  0.021559 -0.016133
# 2022-11-29 -0.005640  0.004723 -0.001532 -0.007896  0.023248  0.000505
# 2022-11-30  0.052761  0.000000  0.027272  0.039057  0.021379  0.022163
# 2022-12-01  0.000081  0.000000 -0.007518 -0.001280  0.001698 -0.008696
#
#               RMS.PA    KER.PA     RI.PA    ISP.MI  ...     LI.PA    BOL.PA  \
# Date                                                ...
# 2022-11-25 -0.005716 -0.004382 -0.019670 -0.000695  ... -0.016740  0.003791
# 2022-11-28  0.011836 -0.000183 -0.002675 -0.019690  ... -0.004480 -0.008499
# 2022-11-29 -0.008021  0.013573  0.002951  0.008743  ...  0.002700 -0.002857
# 2022-11-30  0.032682  0.026240  0.016315 -0.023425  ... -0.013914  0.042980
# 2022-12-01  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
#
#               DIE.BR    GFC.PA  SECU-B.ST   IDVA.SG     FR.PA     LBGUF  \
# Date
# 2022-11-25  0.008333 -0.006218  -0.015145  0.008983  0.001977  0.000781
# 2022-11-28 -0.007163 -0.009385  -0.009383 -0.026710 -0.013251  0.003914
# 2022-11-29 -0.012209 -0.002632  -0.009452  0.009148  0.007429  0.002125
# 2022-11-30  0.025843 -0.002111  -0.033151  0.001236  0.002269  0.002038
# 2022-12-01  0.000000  0.000000   0.001610  0.000000  0.000000  0.000000
#
#               COV.PA     MF.PA
# Date
# 2022-11-25 -0.002625  0.000565
# 2022-11-28 -0.003509 -0.016384
# 2022-11-29 -0.007923  0.000000
# 2022-11-30 -0.015972  0.029293
# 2022-12-01  0.000000  0.000000
#
# [5 rows x 56 columns]

# %% [markdown]
# # 2. First static analysis

# %% [markdown]
# ## a. Details

# %% [markdown]
# In this first practical part we will set up and analyze different portfolio strategies (different optimization techniques) in a fairly simple way by considering the period from 2005 to 2010 as test data. This is a static part that is only carried out to understand the functioning of the different optimization functions. Later we will add a dynamic optimization (definition of new weights every quarter) and in the final part we will take into account transaction costs to be more faithful to reality.

# %%
# We define the start and end dates of our training set
start_train = "2005-01-01"
end_train = "2010-01-01"
end_test = "2022-01-01"

# %%
# We use the separate function of the portfolio_functions module to obtain our training and test DataFrames
rends_train,rends_test = pf.separate(rends,start_train,end_train,end_test)

# We delete the assets that have only null returns or negative annualized returns with the supr_assets function
rends_train,rends_test = pf.supr_assets(rends_train,show=True),pf.supr_assets(rends_test,show=True)
# Out:
# The following assets will be suppressed:
# SAP ISP.MI IDEXF AMS.MC LR.PA G.MI VNA.DE CABK.MC SCMN.SW KBC.BR BNR.DE EBS.VI AENA.MC EXO.AS GBLC.CN RDFN BVI.PA ZAL.DE SIG VIV.PA PNDORA.CO WFDRX MB.MI ATL.MI SECU-B.ST IDVA.SG FR.PA LBGUF MF.PA
# The following assets will be suppressed:
# ISP.MI G.MI CABK.MC EXO.AS GBLC.CN TELIA.ST VIV.PA ATL.MI LI.PA

# %%
# On utilise la fonction separate du module portfolio_functions pour obtenir nos DataFrames d'entrainement et de tests We use the separate function of the portfolio_functions module to obtain our training and test DataFrames
prices_train,prices_test = pf.separate(prices,start_train,end_train,end_test)

# %%
rends_train.head()
# Out:
#                 ASML     MC.PA       NVS    CFR.SW       ABB    RMS.PA  \
# Date
# 2005-01-04 -0.019369 -0.005300 -0.010455 -0.011691  0.003406 -0.006780
# 2005-01-05 -0.014320 -0.015098 -0.003728 -0.021494  0.010862 -0.010921
# 2005-01-06 -0.008771  0.003607  0.001791  0.015251  0.012697  0.001380
# 2005-01-07  0.000451  0.007188 -0.001870 -0.004374 -0.001297 -0.008959
# 2005-01-10  0.013300 -0.006244 -0.006846  0.006278  0.008651  0.019471
#
#               KER.PA     RI.PA    CAP.PA      6S=F  ...      QGEN    TRN.MI  \
# Date                                                ...
# 2005-01-04  0.000674  0.002650 -0.009963 -0.006006  ...  0.025191  0.009412
# 2005-01-05 -0.012129  0.006167 -0.001258  0.000379  ... -0.005236  0.020979
# 2005-01-06  0.004775 -0.003503 -0.006297  0.002661  ...  0.002815 -0.006849
# 2005-01-07  0.010183  0.003515 -0.012252  0.000719  ...  0.012090  0.000000
# 2005-01-10 -0.002016 -0.011384  0.065868 -0.001618  ... -0.029835 -0.002299
#
#             TELIA.ST   RAND.AS    JMT.LS     LI.PA    BOL.PA    DIE.BR  \
# Date
# 2005-01-04  0.003459 -0.001721  0.010152 -0.030769  0.000000  0.007942
# 2005-01-05 -0.000401 -0.021027 -0.010050 -0.015873 -0.008403 -0.004298
# 2005-01-06  0.009390  0.014084  0.005076  0.000000  0.000000 -0.002878
# 2005-01-07  0.002291 -0.006250  0.015152  0.016129 -0.003390  0.019481
# 2005-01-10  0.011951 -0.000699 -0.002985  0.000000  0.002551 -0.006369
#
#               GFC.PA    COV.PA
# Date
# 2005-01-04 -0.021592  0.000000
# 2005-01-05 -0.003448  0.000000
# 2005-01-06 -0.010381 -0.001613
# 2005-01-07  0.021678  0.001616
# 2005-01-10  0.004107  0.004839
#
# [5 rows x 27 columns]

# %%
rends_test.head()
# Out:
#                 ASML     MC.PA       NVS       SAP    CFR.SW       ABB  \
# Date
# 2010-01-04  0.009889  0.004083 -0.039932 -0.000354  0.015476  0.021363
# 2010-01-05  0.011860 -0.004701  0.003084 -0.002142  0.004929  0.010685
# 2010-01-06  0.006494  0.009702 -0.006249  0.020576  0.010129  0.008960
# 2010-01-07 -0.021962  0.011379 -0.002830  0.032464  0.008545  0.014558
# 2010-01-08 -0.030231  0.013502  0.001581  0.001019  0.008923  0.021620
#
#               RMS.PA    KER.PA     RI.PA    CAP.PA  ...     MB.MI    BOL.PA  \
# Date                                                ...
# 2010-01-04  0.003215  0.033001  0.015356  0.043165  ...  0.000000  0.014354
# 2010-01-05  0.005341 -0.014594 -0.024330  0.012444  ...  0.029833  0.002573
# 2010-01-06 -0.003719 -0.012245  0.010952  0.019843  ...  0.000579  0.010265
# 2010-01-07 -0.011412  0.003070 -0.010667 -0.010454  ...  0.022582 -0.000847
# 2010-01-08  0.020067  0.031780 -0.007581  0.004255  ... -0.003397  0.001695
#
#               DIE.BR    GFC.PA  SECU-B.ST  IDVA.SG     FR.PA     LBGUF  \
# Date
# 2010-01-04  0.038481  0.024297   0.008178      0.0  0.031594 -0.006719
# 2010-01-05 -0.002829 -0.001154   0.006940      0.0  0.039518  0.004039
# 2010-01-06 -0.001972 -0.024390  -0.005628      0.0 -0.007983 -0.002643
# 2010-01-07  0.013659 -0.023289  -0.000569      0.0  0.027017  0.006006
# 2010-01-08  0.056226  0.000135   0.005391      0.0  0.000746 -0.006457
#
#               COV.PA     MF.PA
# Date
# 2010-01-04  0.038106  0.049065
# 2010-01-05  0.014845  0.002784
# 2010-01-06 -0.026862  0.011771
# 2010-01-07 -0.015578  0.002195
# 2010-01-08 -0.000139  0.006242
#
# [5 rows x 47 columns]

# %%
sorted(pf.annu_rend_df(rends_train).items(), key=lambda x: x[1], reverse=True)
# Out:
# [('JMT.LS', 0.27929),
#  ('ABB', 0.25192),
#  ('KNEBV.HE', 0.2118),
#  ('DIE.BR', 0.14609),
#  ('BOL.PA', 0.13672),
#  ('QGEN', 0.13343),
#  ('RMS.PA', 0.13278),
#  ('ASML', 0.12253),
#  ('SAMPO.HE', 0.10661),
#  ('COLO-B.CO', 0.09674),
#  ('CFR.SW', 0.07216),
#  ('TRN.MI', 0.06784),
#  ('MC.PA', 0.0654),
#  ('LI.PA', 0.05901),
#  ('CAP.PA', 0.05662),
#  ('RAND.AS', 0.03628),
#  ('PUB.PA', 0.03376),
#  ('TELIA.ST', 0.02811),
#  ('COV.PA', 0.02779),
#  ('HNR1.DE', 0.02695),
#  ('KER.PA', 0.02514),
#  ('RI.PA', 0.0227),
#  ('SHB-A.ST', 0.01086),
#  ('6S=F', 0.00741),
#  ('GFC.PA', 0.0053),
#  ('ADDYY', 0.00435),
#  ('NVS', 0.00347)]

# %% [markdown]
# ## b. Equally Weighted Portfolio

# %% [markdown]
# Certainly the easiest portfolio to create because we just have to allocate this weighting strategy:
# $$
# \boxed{\omega_{i} = \frac{1}{\#\textrm{assets}},\forall i \in\textrm{assets}}
# $$

# %%
# We define a dictionary containing the weights associated with each asset
w_equal = {asset:round(1/len(rends_train.columns),3) for asset in rends_train.columns}

# We define a dictionary containing the weights associated with each asset
for key,value in w_equal.items():
    print(f'Asset considéré : {key} ; poid associé : {value}')
print(f"Somme de l'ensemble des poids : {round(sum(w_equal.values()),5)}")
# We remark that the sum of the weights is greater than 1 which is due to the rounding on the weights
# Out:
# Asset considéré : ASML ; poid associé : 0.037
# Asset considéré : MC.PA ; poid associé : 0.037
# Asset considéré : NVS ; poid associé : 0.037
# Asset considéré : CFR.SW ; poid associé : 0.037
# Asset considéré : ABB ; poid associé : 0.037
# Asset considéré : RMS.PA ; poid associé : 0.037
# Asset considéré : KER.PA ; poid associé : 0.037
# Asset considéré : RI.PA ; poid associé : 0.037
# Asset considéré : CAP.PA ; poid associé : 0.037
# Asset considéré : 6S=F ; poid associé : 0.037
# Asset considéré : SAMPO.HE ; poid associé : 0.037
# Asset considéré : ADDYY ; poid associé : 0.037
# Asset considéré : KNEBV.HE ; poid associé : 0.037
# Asset considéré : PUB.PA ; poid associé : 0.037
# Asset considéré : COLO-B.CO ; poid associé : 0.037
# Asset considéré : SHB-A.ST ; poid associé : 0.037
# Asset considéré : HNR1.DE ; poid associé : 0.037
# Asset considéré : QGEN ; poid associé : 0.037
# Asset considéré : TRN.MI ; poid associé : 0.037
# Asset considéré : TELIA.ST ; poid associé : 0.037
# Asset considéré : RAND.AS ; poid associé : 0.037
# Asset considéré : JMT.LS ; poid associé : 0.037
# Asset considéré : LI.PA ; poid associé : 0.037
# Asset considéré : BOL.PA ; poid associé : 0.037
# Asset considéré : DIE.BR ; poid associé : 0.037
# Asset considéré : GFC.PA ; poid associé : 0.037
# Asset considéré : COV.PA ; poid associé : 0.037
# Somme de l'ensemble des poids : 0.999

# %%
# We calculate the return of our portfolio and we create a new column
Portfolio = pd.Series((rends_train*w_equal.values()).sum(axis=1),name="Portfolio")

# %%
plt.plot(Portfolio,'black')
plt.title("Rendements observés sur la période {} - {}".format(start_train,end_train))
# Out:
# Text(0.5, 1.0, 'Rendements observés sur la période 2005-01-01 - 2010-01-01')

# %%
# The calculation of the annualized return is done with the annu_rend function of the portfolio_functions module
annu_rend = pf.annu_rend(Portfolio,show=True)
annu_rend = pf.portfolio_rend(np.array(list(w_equal.values())),rends_train,show=True)
# The two functions are equivalent, they will be used later

# The calculation of the annualized volatility is done with the annu_vol function of the portfolio_functions module
annu_vol = pf.annu_vol(Portfolio,show=True)
annu_vol = pf.portfolio_vol(np.array(list(w_equal.values())),pf.cov(rends_train),show=True)
annu_var = pf.portfolio_var(np.array(list(w_equal.values())),pf.cov(rends_train),show=True)
# The two functions are equivalent, they will be used later
# Out:
# Annualized return on the period: 12.071%.
# Annualized return on the period: 12.071%.
# Annualized volatility on the period: 19.336%.
# Annualized volatility on the period: 19.336%.
# Annualized variance on the period: 3.739%.

# %% [markdown]
# ## c. Mean-Variance Portfolio

# %% [markdown]
# We are gonna implement some optimization methods taking into account some constraints. Here we want to optimize the weights in order to minimize the volatility of our portfolio while respecting some constraints:
# $$
# \textrm{min}\, \omega^{T}\Sigma\omega\\\textrm{s.t}\, \mu^{T}\omega=\mu_{obj} \, \textrm{and} \, \sum_{i=0}^{n}\omega_{i}=1
# $$
#
# Where $\omega$ is the weights vector, $\Sigma$ the covariance matrix of our asset bucket, $\mu$ is the annualized returns vector and $\mu_{obj}$ is the objective return.

# %%
# To calculate the annualized covariance we use the annu_cov function of the pf module
cov = pf.cov(rends_train)
cov
# Out:
#                ASML     MC.PA       NVS    CFR.SW       ABB    RMS.PA  \
# ASML       0.000627  0.000156  0.000141  0.000134  0.000389  0.000108
# MC.PA      0.000156  0.000373  0.000041  0.000302  0.000239  0.000199
# NVS        0.000141  0.000041  0.000220  0.000024  0.000149  0.000040
# CFR.SW     0.000134  0.000302  0.000024  0.000454  0.000225  0.000190
# ABB        0.000389  0.000239  0.000149  0.000225  0.000686  0.000148
# RMS.PA     0.000108  0.000199  0.000040  0.000190  0.000148  0.000409
# KER.PA     0.000157  0.000322  0.000019  0.000324  0.000255  0.000210
# RI.PA      0.000094  0.000193  0.000056  0.000167  0.000175  0.000138
# CAP.PA     0.000199  0.000283  0.000033  0.000282  0.000270  0.000184
# 6S=F       0.000037 -0.000029  0.000058 -0.000030  0.000025 -0.000015
# SAMPO.HE   0.000133  0.000188  0.000026  0.000212  0.000194  0.000136
# ADDYY      0.000285  0.000189  0.000127  0.000153  0.000345  0.000119
# KNEBV.HE   0.000124  0.000209  0.000008  0.000211  0.000218  0.000160
# PUB.PA     0.000101  0.000193  0.000026  0.000185  0.000185  0.000130
# COLO-B.CO  0.000077  0.000111  0.000041  0.000112  0.000152  0.000106
# SHB-A.ST   0.000161  0.000292  0.000036  0.000308  0.000243  0.000182
# HNR1.DE    0.000119  0.000212  0.000026  0.000201  0.000202  0.000125
# QGEN       0.000209  0.000063  0.000134  0.000053  0.000240  0.000047
# TRN.MI     0.000021  0.000074  0.000013  0.000066  0.000061  0.000057
# TELIA.ST   0.000139  0.000180  0.000048  0.000173  0.000187  0.000120
# RAND.AS    0.000225  0.000306  0.000059  0.000312  0.000332  0.000219
# JMT.LS     0.000066  0.000137  0.000016  0.000143  0.000137  0.000099
# LI.PA      0.000124  0.000227  0.000038  0.000222  0.000209  0.000180
# BOL.PA     0.000055  0.000103  0.000028  0.000116  0.000095  0.000079
# DIE.BR     0.000080  0.000144  0.000021  0.000147  0.000138  0.000104
# GFC.PA     0.000147  0.000204  0.000018  0.000220  0.000198  0.000134
# COV.PA     0.000098  0.000184  0.000024  0.000185  0.000191  0.000160
#
#              KER.PA     RI.PA    CAP.PA      6S=F  ...      QGEN    TRN.MI  \
# ASML       0.000157  0.000094  0.000199  0.000037  ...  0.000209  0.000021
# MC.PA      0.000322  0.000193  0.000283 -0.000029  ...  0.000063  0.000074
# NVS        0.000019  0.000056  0.000033  0.000058  ...  0.000134  0.000013
# CFR.SW     0.000324  0.000167  0.000282 -0.000030  ...  0.000053  0.000066
# ABB        0.000255  0.000175  0.000270  0.000025  ...  0.000240  0.000061
# RMS.PA     0.000210  0.000138  0.000184 -0.000015  ...  0.000047  0.000057
# KER.PA     0.000548  0.000224  0.000321 -0.000030  ...  0.000050  0.000072
# RI.PA      0.000224  0.000404  0.000193 -0.000014  ...  0.000051  0.000055
# CAP.PA     0.000321  0.000193  0.000565 -0.000041  ...  0.000080  0.000072
# 6S=F      -0.000030 -0.000014 -0.000041  0.000089  ...  0.000049 -0.000020
# SAMPO.HE   0.000231  0.000122  0.000210 -0.000025  ...  0.000071  0.000049
# ADDYY      0.000198  0.000143  0.000179  0.000047  ...  0.000195  0.000030
# KNEBV.HE   0.000233  0.000139  0.000227 -0.000030  ...  0.000050  0.000055
# PUB.PA     0.000232  0.000166  0.000216 -0.000026  ...  0.000063  0.000056
# COLO-B.CO  0.000116  0.000093  0.000116 -0.000004  ...  0.000056  0.000038
# SHB-A.ST   0.000323  0.000193  0.000298 -0.000043  ...  0.000065  0.000071
# HNR1.DE    0.000257  0.000161  0.000244 -0.000037  ...  0.000090  0.000070
# QGEN       0.000050  0.000051  0.000080  0.000049  ...  0.000455  0.000037
# TRN.MI     0.000072  0.000055  0.000072 -0.000020  ...  0.000037  0.000179
# TELIA.ST   0.000196  0.000127  0.000192 -0.000022  ...  0.000059  0.000062
# RAND.AS    0.000356  0.000205  0.000342 -0.000031  ...  0.000130  0.000084
# JMT.LS     0.000161  0.000131  0.000141 -0.000021  ...  0.000053  0.000034
# LI.PA      0.000256  0.000163  0.000241 -0.000029  ...  0.000086  0.000067
# BOL.PA     0.000118  0.000067  0.000119 -0.000014  ...  0.000051  0.000041
# DIE.BR     0.000194  0.000100  0.000155 -0.000014  ...  0.000042  0.000033
# GFC.PA     0.000261  0.000153  0.000219 -0.000023  ...  0.000067  0.000038
# COV.PA     0.000227  0.000161  0.000185 -0.000024  ...  0.000081  0.000050
#
#            TELIA.ST   RAND.AS    JMT.LS     LI.PA    BOL.PA    DIE.BR  \
# ASML       0.000139  0.000225  0.000066  0.000124  0.000055  0.000080
# MC.PA      0.000180  0.000306  0.000137  0.000227  0.000103  0.000144
# NVS        0.000048  0.000059  0.000016  0.000038  0.000028  0.000021
# CFR.SW     0.000173  0.000312  0.000143  0.000222  0.000116  0.000147
# ABB        0.000187  0.000332  0.000137  0.000209  0.000095  0.000138
# RMS.PA     0.000120  0.000219  0.000099  0.000180  0.000079  0.000104
# KER.PA     0.000196  0.000356  0.000161  0.000256  0.000118  0.000194
# RI.PA      0.000127  0.000205  0.000131  0.000163  0.000067  0.000100
# CAP.PA     0.000192  0.000342  0.000141  0.000241  0.000119  0.000155
# 6S=F      -0.000022 -0.000031 -0.000021 -0.000029 -0.000014 -0.000014
# SAMPO.HE   0.000141  0.000275  0.000126  0.000196  0.000073  0.000125
# ADDYY      0.000131  0.000246  0.000104  0.000137  0.000081  0.000110
# KNEBV.HE   0.000152  0.000271  0.000107  0.000193  0.000097  0.000114
# PUB.PA     0.000135  0.000226  0.000109  0.000176  0.000089  0.000112
# COLO-B.CO  0.000087  0.000146  0.000070  0.000105  0.000058  0.000058
# SHB-A.ST   0.000281  0.000343  0.000138  0.000283  0.000111  0.000198
# HNR1.DE    0.000168  0.000249  0.000158  0.000224  0.000110  0.000144
# QGEN       0.000059  0.000130  0.000053  0.000086  0.000051  0.000042
# TRN.MI     0.000062  0.000084  0.000034  0.000067  0.000041  0.000033
# TELIA.ST   0.000412  0.000228  0.000097  0.000136  0.000067  0.000103
# RAND.AS    0.000228  0.000776  0.000185  0.000286  0.000131  0.000199
# JMT.LS     0.000097  0.000185  0.000423  0.000148  0.000040  0.000084
# LI.PA      0.000136  0.000286  0.000148  0.000574  0.000091  0.000154
# BOL.PA     0.000067  0.000131  0.000040  0.000091  0.000340  0.000079
# DIE.BR     0.000103  0.000199  0.000084  0.000154  0.000079  0.000413
# GFC.PA     0.000143  0.000279  0.000128  0.000316  0.000106  0.000148
# COV.PA     0.000105  0.000222  0.000115  0.000291  0.000102  0.000140
#
#              GFC.PA    COV.PA
# ASML       0.000147  0.000098
# MC.PA      0.000204  0.000184
# NVS        0.000018  0.000024
# CFR.SW     0.000220  0.000185
# ABB        0.000198  0.000191
# RMS.PA     0.000134  0.000160
# KER.PA     0.000261  0.000227
# RI.PA      0.000153  0.000161
# CAP.PA     0.000219  0.000185
# 6S=F      -0.000023 -0.000024
# SAMPO.HE   0.000190  0.000153
# ADDYY      0.000140  0.000100
# KNEBV.HE   0.000162  0.000158
# PUB.PA     0.000154  0.000146
# COLO-B.CO  0.000098  0.000096
# SHB-A.ST   0.000253  0.000216
# HNR1.DE    0.000198  0.000179
# QGEN       0.000067  0.000081
# TRN.MI     0.000038  0.000050
# TELIA.ST   0.000143  0.000105
# RAND.AS    0.000279  0.000222
# JMT.LS     0.000128  0.000115
# LI.PA      0.000316  0.000291
# BOL.PA     0.000106  0.000102
# DIE.BR     0.000148  0.000140
# GFC.PA     0.000608  0.000290
# COV.PA     0.000290  0.000636
#
# [27 rows x 27 columns]

# %% [markdown]
# Now all the functions are ready to plot an efficient frontier. The important point to know is the bounderies off my weights. We decided to autorise the short selling of assets in order to fit with the gmw portfolio formula.

# %%
# The function opt_mean_variance returns the weights, the annualized return and the annualized volatility
w,r,vol = pf.opt_mean_variance(rends_train,pf.cov(rends_train),obj_rend=0.12071,show=True)
# Out:
# Annualized return on the period: 12.071%.
# Annualized volatility on the period: 9.814%.

# %% [markdown]
# With a portfolio with the same return than the equally weighted portfolio, we found a smaller volatility. It's coherent because the equally weighted portfolio is note on the efficient frontier.

# %% [markdown]
# We created a function in order to find the global minimum variance weight and after return and volatility. The GMV weights are given by this formula:
# $$
# \boxed{\omega = \frac{\Sigma^{-1}1}{1\Sigma^{-1}1}}
# $$

# %%
gmv_w,gmv_r, gmv_v = pf.gmv_portfolio(rends_train,cov,show=True)
# Out:
# Annualized return on the period: 6.813%.
# Annualized volatility on the period: 9.148%.

# %% [markdown]
# We plot the efficient frontier using pf.efficient_frontier with the variable plot = True.

# %%
eff = pf.efficient_frontier(rends_train,cov,min=0.02,max=0.3,number=20,plot=True)

# %% [markdown]
# ## d. Adding Capital Market Line

# %% [markdown]
# Calculating the Capital Market Line is just a modification of a constraint in the optimisation function. A new parameter is adding, it's the annualized risk free rate. The new formula for the constraint is the following:
# $$
# \textrm{min}\, \omega^{T}\Sigma\omega\\\textrm{s.t}\, \mu^{T}\omega+(1-\sum_{i=0}^{n}\omega_{i})r_{\textrm{risk-free rate}}=\mu_{obj} \, \textrm{and} \, \sum_{i=0}^{n}\omega_{i}=1
# $$
# To modelise this new constraint we just have to modify the optimization function by modifying the covariance matrix, and the returns DataFrame by adding the risk-free rate in them. We also create the new constraint.

# %%
eff,eff_rf = pf.efficient_frontier(rends_train,cov,min=0.01,max=0.7,risk_free = 0.02,number=20,plot=True)

# %% [markdown]
# # 3. Dynamic analysis

# %% [markdown]
# In order to create a dynamic analysis we will use a function which create DataFrame as many as we want.

# %%
# If we want to recalculate the weights of the portfolio 4 times each year
dfs = pf.dynamic_df(rends_train,period_per_year=4)

# %%
for i in dfs.keys():
    # We check that the dates are correct for each DataFrame
    print(dfs[i].index[0],dfs[i].index[-1])
    print(dfs[i].shape)
# Out:
# 2005-01-04 00:00:00 2005-04-01 00:00:00
# (64, 19)
# 2005-04-04 00:00:00 2005-07-01 00:00:00
# (65, 21)
# 2005-07-04 00:00:00 2005-09-30 00:00:00
# (65, 22)
# 2005-10-03 00:00:00 2005-12-30 00:00:00
# (65, 21)
# 2006-01-02 00:00:00 2006-03-30 00:00:00
# (64, 23)
# 2006-03-31 00:00:00 2006-06-29 00:00:00
# (65, 2)
# 2006-06-30 00:00:00 2006-09-28 00:00:00
# (65, 24)
# 2006-09-29 00:00:00 2006-12-28 00:00:00
# (65, 22)
# 2006-12-29 00:00:00 2007-03-28 00:00:00
# (64, 14)
# 2007-03-29 00:00:00 2007-06-28 00:00:00
# (65, 14)
# 2007-06-29 00:00:00 2007-09-27 00:00:00
# (65, 11)
# 2007-09-28 00:00:00 2007-12-28 00:00:00
# (65, 10)
# 2007-12-31 00:00:00 2008-03-31 00:00:00
# (64, 7)
# 2008-04-01 00:00:00 2008-06-30 00:00:00
# (65, 5)
# 2008-07-01 00:00:00 2008-09-29 00:00:00
# (65, 8)
# 2008-09-30 00:00:00 2008-12-30 00:00:00
# (65, 2)
# 2008-12-31 00:00:00 2009-03-31 00:00:00
# (64, 9)
# 2009-04-01 00:00:00 2009-07-01 00:00:00
# (65, 26)
# 2009-07-02 00:00:00 2009-09-30 00:00:00
# (65, 27)
# 2009-10-01 00:00:00 2009-12-31 00:00:00
# (65, 19)

# %%
weights = {}
# For each period we calculate the weights of the portfolio and we store them in the dictionary
for i in dfs.keys():
    w,r,v = pf.opt_mean_variance(dfs[i],cov=dfs[i].cov(),obj_rend=0.10)
    weights[i] = w

# %%
for key,value in weights.items():
    # We check that the weights are different for each period and that they sum to 1
    print(f'Weights for the portfolio at the period {key}:\n {value}')
    print(f'Sum of the weights: {round(sum(value.values()),5)}')
# Out:
# Weights for the portfolio at the period 1:
#  {'ASML': 0.012, 'MC.PA': 0.061, 'ABB': 0.055, 'RMS.PA': 0.091, 'KER.PA': 0.126, 'CAP.PA': 0.009, 'SAMPO.HE': -0.008, 'ADDYY': 0.54, 'PUB.PA': 0.181, 'HNR1.DE': 0.008, 'QGEN': -0.021, 'TELIA.ST': -0.024, 'RAND.AS': 0.021, 'JMT.LS': 0.015, 'LI.PA': 0.058, 'BOL.PA': -0.052, 'DIE.BR': -0.095, 'GFC.PA': -0.004, 'COV.PA': 0.026}
# Sum of the weights: 0.999
# Weights for the portfolio at the period 2:
#  {'ASML': 0.001, 'MC.PA': -0.134, 'NVS': -0.047, 'CFR.SW': 0.044, 'ABB': -0.017, 'RMS.PA': -0.03, 'KER.PA': 0.136, 'RI.PA': 0.038, '6S=F': 0.653, 'SAMPO.HE': 0.02, 'ADDYY': 0.102, 'KNEBV.HE': 0.025, 'PUB.PA': -0.001, 'COLO-B.CO': 0.016, 'HNR1.DE': -0.02, 'QGEN': 0.01, 'TRN.MI': 0.095, 'LI.PA': 0.027, 'BOL.PA': 0.011, 'GFC.PA': 0.062, 'COV.PA': 0.01}
# Sum of the weights: 1.001
# Weights for the portfolio at the period 3:
#  {'ASML': 0.047, 'MC.PA': 0.06, 'NVS': 0.27, 'CFR.SW': -0.137, 'ABB': -0.015, 'RMS.PA': 0.066, 'KER.PA': 0.094, 'RI.PA': -0.054, 'CAP.PA': -0.107, 'SAMPO.HE': 0.139, 'KNEBV.HE': 0.086, 'PUB.PA': 0.011, 'COLO-B.CO': 0.122, 'SHB-A.ST': -0.061, 'QGEN': 0.006, 'RAND.AS': 0.018, 'JMT.LS': 0.209, 'LI.PA': 0.175, 'BOL.PA': 0.019, 'DIE.BR': -0.084, 'GFC.PA': 0.093, 'COV.PA': 0.043}
# Sum of the weights: 1.0
# Weights for the portfolio at the period 4:
#  {'ASML': 0.015, 'MC.PA': 0.005, 'NVS': -0.01, 'CFR.SW': -0.001, 'ABB': -0.017, 'RMS.PA': 0.001, 'KER.PA': 0.051, 'RI.PA': 0.07, 'CAP.PA': 0.015, '6S=F': 0.641, 'SAMPO.HE': -0.022, 'ADDYY': -0.002, 'KNEBV.HE': 0.004, 'PUB.PA': 0.038, 'COLO-B.CO': -0.001, 'SHB-A.ST': -0.056, 'HNR1.DE': 0.008, 'TELIA.ST': 0.053, 'RAND.AS': 0.038, 'JMT.LS': 0.175, 'DIE.BR': -0.003}
# Sum of the weights: 1.002
# Weights for the portfolio at the period 5:
#  {'MC.PA': -0.024, 'NVS': 0.183, 'CFR.SW': 0.019, 'ABB': -0.032, 'KER.PA': 0.086, 'RI.PA': 0.005, 'CAP.PA': -0.064, 'SAMPO.HE': 0.039, 'KNEBV.HE': 0.057, 'PUB.PA': 0.289, 'COLO-B.CO': 0.053, 'SHB-A.ST': 0.001, 'HNR1.DE': 0.013, 'QGEN': -0.032, 'TRN.MI': 0.193, 'TELIA.ST': 0.061, 'RAND.AS': -0.067, 'JMT.LS': 0.21, 'LI.PA': -0.024, 'BOL.PA': -0.096, 'DIE.BR': 0.047, 'GFC.PA': 0.075, 'COV.PA': 0.007}
# Sum of the weights: 0.999
# Weights for the portfolio at the period 6:
#  {'6S=F': 0.501, 'DIE.BR': 0.497}
# Sum of the weights: 0.998
# Weights for the portfolio at the period 7:
#  {'ASML': -0.014, 'MC.PA': -0.038, 'NVS': 0.32, 'CFR.SW': -0.082, 'ABB': -0.008, 'RMS.PA': 0.062, 'KER.PA': -0.076, 'RI.PA': 0.012, 'SAMPO.HE': -0.052, 'KNEBV.HE': -0.041, 'PUB.PA': 0.11, 'COLO-B.CO': 0.119, 'SHB-A.ST': 0.072, 'HNR1.DE': -0.099, 'QGEN': 0.022, 'TRN.MI': 0.134, 'TELIA.ST': 0.013, 'RAND.AS': -0.025, 'JMT.LS': 0.299, 'LI.PA': -0.113, 'BOL.PA': 0.018, 'DIE.BR': 0.074, 'GFC.PA': 0.234, 'COV.PA': 0.057}
# Sum of the weights: 0.998
# Weights for the portfolio at the period 8:
#  {'ASML': 0.064, 'CFR.SW': -0.108, 'ABB': -0.189, 'RMS.PA': -0.066, 'RI.PA': 0.05, 'CAP.PA': 0.03, 'SAMPO.HE': 0.019, 'ADDYY': 0.058, 'KNEBV.HE': 0.155, 'PUB.PA': 0.246, 'COLO-B.CO': 0.057, 'SHB-A.ST': -0.088, 'HNR1.DE': 0.13, 'TRN.MI': 0.16, 'TELIA.ST': -0.087, 'RAND.AS': 0.051, 'JMT.LS': 0.149, 'LI.PA': -0.099, 'BOL.PA': 0.199, 'DIE.BR': 0.161, 'GFC.PA': 0.02, 'COV.PA': 0.09}
# Sum of the weights: 1.002
# Weights for the portfolio at the period 9:
#  {'MC.PA': 0.266, 'RMS.PA': -0.087, 'KER.PA': 0.14, 'CAP.PA': -0.235, 'SAMPO.HE': 0.068, 'ADDYY': 0.143, 'PUB.PA': 0.186, 'QGEN': 0.044, 'TRN.MI': 0.23, 'TELIA.ST': 0.269, 'RAND.AS': -0.222, 'JMT.LS': 0.072, 'DIE.BR': -0.044, 'GFC.PA': 0.169}
# Sum of the weights: 0.999
# Weights for the portfolio at the period 10:
#  {'ASML': 0.137, 'MC.PA': 0.22, 'CFR.SW': -0.08, 'ABB': -0.179, 'KER.PA': 0.031, 'RI.PA': 0.372, 'ADDYY': -0.01, 'KNEBV.HE': -0.059, 'HNR1.DE': 0.104, 'QGEN': 0.031, 'RAND.AS': 0.037, 'JMT.LS': 0.068, 'BOL.PA': 0.224, 'DIE.BR': 0.103}
# Sum of the weights: 0.999
# Weights for the portfolio at the period 11:
#  {'ASML': 0.14, 'CFR.SW': 0.007, 'ABB': -0.278, 'KER.PA': 0.132, 'ADDYY': 0.37, 'KNEBV.HE': 0.045, 'COLO-B.CO': 0.031, 'SHB-A.ST': 0.001, 'QGEN': 0.058, 'TRN.MI': 0.479, 'TELIA.ST': 0.014}
# Sum of the weights: 0.999
# Weights for the portfolio at the period 12:
#  {'CFR.SW': 0.216, 'ABB': -0.118, 'RMS.PA': -0.098, 'RI.PA': 0.323, 'ADDYY': 0.005, 'SHB-A.ST': 0.135, 'QGEN': 0.005, 'TRN.MI': 0.407, 'TELIA.ST': 0.149, 'JMT.LS': -0.025}
# Sum of the weights: 0.999
# Weights for the portfolio at the period 13:
#  {'6S=F': 0.63, 'KNEBV.HE': -0.177, 'HNR1.DE': 0.237, 'RAND.AS': -0.184, 'LI.PA': -0.149, 'BOL.PA': 0.612, 'COV.PA': 0.031}
# Sum of the weights: 1.0
# Weights for the portfolio at the period 14:
#  {'NVS': 0.351, 'ABB': 0.078, 'RMS.PA': -0.04, 'RI.PA': 0.596, 'CAP.PA': 0.016}
# Sum of the weights: 1.001
# Weights for the portfolio at the period 15:
#  {'NVS': -0.02, 'RMS.PA': -0.019, '6S=F': 0.739, 'SAMPO.HE': 0.23, 'PUB.PA': 0.229, 'SHB-A.ST': -0.067, 'QGEN': -0.078, 'JMT.LS': -0.014}
# Sum of the weights: 1.0
# Weights for the portfolio at the period 16:
#  {'ASML': -0.099, '6S=F': 1.0}
# Sum of the weights: 0.901
# Weights for the portfolio at the period 17:
#  {'ASML': 0.101, 'MC.PA': -0.007, 'KER.PA': -0.054, 'KNEBV.HE': -0.001, 'PUB.PA': 0.284, 'HNR1.DE': 0.005, 'TRN.MI': 0.599, 'TELIA.ST': 0.096, 'DIE.BR': -0.023}
# Sum of the weights: 1.0
# Weights for the portfolio at the period 18:
#  {'ASML': -0.046, 'MC.PA': 0.016, 'NVS': 0.301, 'CFR.SW': -0.013, 'ABB': 0.058, 'RMS.PA': 0.062, 'KER.PA': 0.01, 'RI.PA': 0.017, 'CAP.PA': 0.076, 'SAMPO.HE': 0.031, 'ADDYY': 0.013, 'KNEBV.HE': -0.012, 'PUB.PA': 0.074, 'COLO-B.CO': 0.075, 'SHB-A.ST': -0.001, 'HNR1.DE': -0.004, 'QGEN': 0.066, 'TRN.MI': 0.349, 'TELIA.ST': -0.025, 'RAND.AS': -0.138, 'JMT.LS': 0.081, 'LI.PA': -0.043, 'BOL.PA': -0.055, 'DIE.BR': 0.059, 'GFC.PA': 0.037, 'COV.PA': 0.01}
# Sum of the weights: 0.998
# Weights for the portfolio at the period 19:
#  {'ASML': -0.048, 'MC.PA': 0.08, 'NVS': -0.032, 'CFR.SW': -0.009, 'ABB': -0.032, 'RMS.PA': 0.014, 'KER.PA': -0.033, 'RI.PA': -0.043, 'CAP.PA': 0.005, '6S=F': 0.825, 'SAMPO.HE': 0.008, 'ADDYY': 0.009, 'KNEBV.HE': -0.095, 'PUB.PA': 0.028, 'COLO-B.CO': 0.027, 'SHB-A.ST': -0.019, 'HNR1.DE': 0.064, 'QGEN': -0.01, 'TRN.MI': 0.15, 'TELIA.ST': 0.037, 'RAND.AS': 0.011, 'JMT.LS': 0.009, 'LI.PA': 0.002, 'BOL.PA': 0.04, 'DIE.BR': -0.006, 'GFC.PA': 0.012, 'COV.PA': 0.007}
# Sum of the weights: 1.001
# Weights for the portfolio at the period 20:
#  {'ASML': 0.014, 'MC.PA': 0.016, 'NVS': 0.049, 'CFR.SW': -0.041, 'RI.PA': 0.031, '6S=F': 0.871, 'ADDYY': 0.022, 'KNEBV.HE': -0.005, 'PUB.PA': 0.069, 'COLO-B.CO': -0.0, 'SHB-A.ST': -0.04, 'HNR1.DE': -0.013, 'QGEN': -0.001, 'TRN.MI': 0.033, 'TELIA.ST': -0.003, 'RAND.AS': 0.017, 'JMT.LS': -0.033, 'LI.PA': -0.021, 'DIE.BR': 0.033}
# Sum of the weights: 0.998

# %% [markdown]
# If we want to vizualise the change in weights we can create pie charts and see the evolution of each weights attribution.

# %%
pf.plot_weights(weights[6])

# %% [markdown]
# It works!

# %% [markdown]
# # 4. Adding Transactions costs

# %% [markdown]
# We assume that the transaction cost is equal to 0.01% of the share price. I we assume that we currently have $\omega_{0}$ of a share $S$ with a price $P_{S}$ and we want to have $\omega_{1}$ of this share, the transaction cost will be equal to:
# $$
# \tau_{S} = 0.001*P_{S}(\omega_{1}-\omega_{0})
# $$
# This value is negative if we sell shares and positive if we buy shares.
#
# The cost of all the transactions during the rebalancing of our portfolio is equal to:
# $$
# \tau_{P} = 0.001*\sum_{1}^{n}(P_{S_{i}}(\omega_{S_{i,1}}-\omega_{S_{i,0}}))
# $$

# %% [markdown]
# In order to implement this strategy we will use the element of the third part.

# %%
weights_tc = {}
# For each period we calculate the weights of the portfolio and we store them in the dictionary
for i in dfs.keys():
    if i == 1:
        w,r,v = pf.opt_mean_variance_tc(rends=dfs[i],last_prices=prices[dfs[i].columns].loc[dfs[i].index[-1]],cov=dfs[i].cov(),obj_rend=0.10)
    else:
        w,r,v = pf.opt_mean_variance_tc(rends=dfs[i],last_prices=prices[dfs[i].columns].loc[dfs[i].index[-1]],last_weights=weights_tc[i-1],cov=dfs[i].cov(),obj_rend=0.10)
    weights_tc[i] = w
# Out:
# Warning : the sum of the weights is less than 0.9.
# We take the weights of the previous period.

# %%
for key,value in weights_tc.items():
    # We check that the weights are different for each period and that they sum to 1
    print(f'Weights for the portfolio at the period {key}:\n {value}')
    print(f'Sum of the weights: {round(sum(value.values()),5)}')
# Out:
# Weights for the portfolio at the period 1:
#  {'ASML': 0.011, 'MC.PA': 0.072, 'ABB': 0.057, 'RMS.PA': 0.088, 'KER.PA': 0.115, 'CAP.PA': 0.005, 'SAMPO.HE': -0.012, 'ADDYY': 0.566, 'PUB.PA': 0.189, 'HNR1.DE': 0.016, 'QGEN': -0.021, 'TELIA.ST': -0.021, 'RAND.AS': 0.018, 'JMT.LS': 0.001, 'LI.PA': 0.065, 'BOL.PA': -0.06, 'DIE.BR': -0.102, 'GFC.PA': -0.012, 'COV.PA': 0.024}
# Sum of the weights: 0.999
# Weights for the portfolio at the period 2:
#  {'ASML': -0.002, 'MC.PA': -0.135, 'NVS': -0.043, 'CFR.SW': 0.051, 'ABB': -0.014, 'RMS.PA': -0.027, 'KER.PA': 0.123, 'RI.PA': 0.041, '6S=F': 0.624, 'SAMPO.HE': 0.029, 'ADDYY': 0.119, 'KNEBV.HE': 0.026, 'PUB.PA': -0.005, 'COLO-B.CO': 0.021, 'HNR1.DE': -0.029, 'QGEN': 0.005, 'TRN.MI': 0.094, 'LI.PA': 0.031, 'BOL.PA': 0.016, 'GFC.PA': 0.063, 'COV.PA': 0.012}
# Sum of the weights: 1.0
# Weights for the portfolio at the period 3:
#  {'ASML': 0.054, 'MC.PA': 0.065, 'NVS': 0.258, 'CFR.SW': -0.138, 'ABB': -0.014, 'RMS.PA': 0.061, 'KER.PA': 0.085, 'RI.PA': -0.06, 'CAP.PA': -0.114, 'SAMPO.HE': 0.151, 'KNEBV.HE': 0.088, 'PUB.PA': 0.002, 'COLO-B.CO': 0.134, 'SHB-A.ST': -0.066, 'QGEN': 0.009, 'RAND.AS': 0.016, 'JMT.LS': 0.235, 'LI.PA': 0.185, 'BOL.PA': 0.012, 'DIE.BR': -0.081, 'GFC.PA': 0.081, 'COV.PA': 0.037}
# Sum of the weights: 1.0
# Weights for the portfolio at the period 4:
#  {'ASML': 0.017, 'MC.PA': 0.011, 'NVS': -0.007, 'CFR.SW': -0.006, 'ABB': -0.017, 'RMS.PA': 0.004, 'KER.PA': 0.058, 'RI.PA': 0.076, 'CAP.PA': 0.013, '6S=F': 0.628, 'SAMPO.HE': -0.025, 'ADDYY': -0.003, 'KNEBV.HE': 0.005, 'PUB.PA': 0.037, 'COLO-B.CO': -0.001, 'SHB-A.ST': -0.061, 'HNR1.DE': 0.006, 'TELIA.ST': 0.054, 'RAND.AS': 0.04, 'JMT.LS': 0.172, 'DIE.BR': -0.003}
# Sum of the weights: 0.998
# Weights for the portfolio at the period 5:
#  {'MC.PA': -0.032, 'NVS': 0.186, 'CFR.SW': 0.023, 'ABB': -0.03, 'KER.PA': 0.082, 'RI.PA': 0.003, 'CAP.PA': -0.066, 'SAMPO.HE': 0.037, 'KNEBV.HE': 0.06, 'PUB.PA': 0.295, 'COLO-B.CO': 0.055, 'SHB-A.ST': 0.002, 'HNR1.DE': 0.017, 'QGEN': -0.033, 'TRN.MI': 0.198, 'TELIA.ST': 0.062, 'RAND.AS': -0.07, 'JMT.LS': 0.21, 'LI.PA': -0.026, 'BOL.PA': -0.098, 'DIE.BR': 0.05, 'GFC.PA': 0.073, 'COV.PA': 0.005}
# Sum of the weights: 1.003
# Weights for the portfolio at the period 6:
#  {'MC.PA': -0.032, 'NVS': 0.186, 'CFR.SW': 0.023, 'ABB': -0.03, 'KER.PA': 0.082, 'RI.PA': 0.003, 'CAP.PA': -0.066, 'SAMPO.HE': 0.037, 'KNEBV.HE': 0.06, 'PUB.PA': 0.295, 'COLO-B.CO': 0.055, 'SHB-A.ST': 0.002, 'HNR1.DE': 0.017, 'QGEN': -0.033, 'TRN.MI': 0.198, 'TELIA.ST': 0.062, 'RAND.AS': -0.07, 'JMT.LS': 0.21, 'LI.PA': -0.026, 'BOL.PA': -0.098, 'DIE.BR': 0.05, 'GFC.PA': 0.073, 'COV.PA': 0.005}
# Sum of the weights: 1.003
# Weights for the portfolio at the period 7:
#  {'ASML': -0.012, 'MC.PA': -0.043, 'NVS': 0.315, 'CFR.SW': -0.074, 'ABB': -0.01, 'RMS.PA': 0.06, 'KER.PA': -0.085, 'RI.PA': 0.009, 'SAMPO.HE': -0.052, 'KNEBV.HE': -0.038, 'PUB.PA': 0.115, 'COLO-B.CO': 0.121, 'SHB-A.ST': 0.071, 'HNR1.DE': -0.1, 'QGEN': 0.024, 'TRN.MI': 0.142, 'TELIA.ST': 0.013, 'RAND.AS': -0.025, 'JMT.LS': 0.306, 'LI.PA': -0.113, 'BOL.PA': 0.018, 'DIE.BR': 0.075, 'GFC.PA': 0.225, 'COV.PA': 0.056}
# Sum of the weights: 0.998
# Weights for the portfolio at the period 8:
#  {'ASML': 0.058, 'CFR.SW': -0.103, 'ABB': -0.187, 'RMS.PA': -0.06, 'RI.PA': 0.03, 'CAP.PA': 0.028, 'SAMPO.HE': 0.016, 'ADDYY': 0.06, 'KNEBV.HE': 0.158, 'PUB.PA': 0.247, 'COLO-B.CO': 0.059, 'SHB-A.ST': -0.081, 'HNR1.DE': 0.114, 'TRN.MI': 0.176, 'TELIA.ST': -0.083, 'RAND.AS': 0.045, 'JMT.LS': 0.156, 'LI.PA': -0.093, 'BOL.PA': 0.202, 'DIE.BR': 0.159, 'GFC.PA': 0.01, 'COV.PA': 0.089}
# Sum of the weights: 1.0
# Weights for the portfolio at the period 9:
#  {'MC.PA': 0.275, 'RMS.PA': -0.123, 'KER.PA': 0.104, 'CAP.PA': -0.241, 'SAMPO.HE': 0.067, 'ADDYY': 0.155, 'PUB.PA': 0.185, 'QGEN': 0.047, 'TRN.MI': 0.271, 'TELIA.ST': 0.304, 'RAND.AS': -0.243, 'JMT.LS': 0.078, 'DIE.BR': -0.044, 'GFC.PA': 0.164}
# Sum of the weights: 0.999
# Weights for the portfolio at the period 10:
#  {'ASML': 0.138, 'MC.PA': 0.232, 'CFR.SW': -0.076, 'ABB': -0.202, 'KER.PA': 0.01, 'RI.PA': 0.362, 'ADDYY': -0.015, 'KNEBV.HE': -0.051, 'HNR1.DE': 0.104, 'QGEN': 0.033, 'RAND.AS': 0.046, 'JMT.LS': 0.068, 'BOL.PA': 0.25, 'DIE.BR': 0.1}
# Sum of the weights: 0.999
# Weights for the portfolio at the period 11:
#  {'ASML': 0.136, 'CFR.SW': 0.024, 'ABB': -0.285, 'KER.PA': 0.091, 'ADDYY': 0.404, 'KNEBV.HE': 0.048, 'COLO-B.CO': 0.002, 'SHB-A.ST': 0.017, 'QGEN': 0.056, 'TRN.MI': 0.514, 'TELIA.ST': -0.007}
# Sum of the weights: 1.0
# Weights for the portfolio at the period 12:
#  {'CFR.SW': 0.231, 'ABB': -0.123, 'RMS.PA': -0.127, 'RI.PA': 0.282, 'ADDYY': 0.0, 'SHB-A.ST': 0.178, 'QGEN': 0.007, 'TRN.MI': 0.432, 'TELIA.ST': 0.138, 'JMT.LS': -0.018}
# Sum of the weights: 1.0
# Weights for the portfolio at the period 13:
#  {'6S=F': 0.647, 'KNEBV.HE': -0.131, 'HNR1.DE': 0.201, 'RAND.AS': -0.152, 'LI.PA': -0.078, 'BOL.PA': 0.647, 'COV.PA': -0.135}
# Sum of the weights: 0.999
# Weights for the portfolio at the period 14:
#  {'NVS': 0.356, 'ABB': 0.086, 'RMS.PA': -0.084, 'RI.PA': 0.619, 'CAP.PA': 0.024}
# Sum of the weights: 1.001
# Weights for the portfolio at the period 15:
#  {'NVS': -0.03, 'RMS.PA': -0.03, '6S=F': 0.75, 'SAMPO.HE': 0.222, 'PUB.PA': 0.22, 'SHB-A.ST': -0.047, 'QGEN': -0.076, 'JMT.LS': -0.009}
# Sum of the weights: 1.0
# Weights for the portfolio at the period 16:
#  {'ASML': -0.098, '6S=F': 1.0}
# Sum of the weights: 0.902
# Weights for the portfolio at the period 17:
#  {'ASML': 0.101, 'MC.PA': -0.01, 'KER.PA': -0.054, 'KNEBV.HE': -0.001, 'PUB.PA': 0.287, 'HNR1.DE': 0.004, 'TRN.MI': 0.6, 'TELIA.ST': 0.1, 'DIE.BR': -0.028}
# Sum of the weights: 0.999
# Weights for the portfolio at the period 18:
#  {'ASML': -0.048, 'MC.PA': 0.017, 'NVS': 0.301, 'CFR.SW': -0.012, 'ABB': 0.061, 'RMS.PA': 0.059, 'KER.PA': 0.01, 'RI.PA': 0.015, 'CAP.PA': 0.08, 'SAMPO.HE': 0.031, 'ADDYY': 0.012, 'KNEBV.HE': -0.015, 'PUB.PA': 0.076, 'COLO-B.CO': 0.078, 'SHB-A.ST': -0.0, 'HNR1.DE': -0.004, 'QGEN': 0.064, 'TRN.MI': 0.356, 'TELIA.ST': -0.024, 'RAND.AS': -0.14, 'JMT.LS': 0.078, 'LI.PA': -0.044, 'BOL.PA': -0.057, 'DIE.BR': 0.058, 'GFC.PA': 0.038, 'COV.PA': 0.009}
# Sum of the weights: 0.999
# Weights for the portfolio at the period 19:
#  {'ASML': -0.047, 'MC.PA': 0.078, 'NVS': -0.025, 'CFR.SW': -0.009, 'ABB': -0.034, 'RMS.PA': 0.009, 'KER.PA': -0.03, 'RI.PA': -0.042, 'CAP.PA': 0.005, '6S=F': 0.814, 'SAMPO.HE': 0.009, 'ADDYY': 0.008, 'KNEBV.HE': -0.094, 'PUB.PA': 0.028, 'COLO-B.CO': 0.028, 'SHB-A.ST': -0.021, 'HNR1.DE': 0.062, 'QGEN': -0.012, 'TRN.MI': 0.154, 'TELIA.ST': 0.036, 'RAND.AS': 0.013, 'JMT.LS': 0.01, 'LI.PA': 0.003, 'BOL.PA': 0.039, 'DIE.BR': -0.005, 'GFC.PA': 0.013, 'COV.PA': 0.008}
# Sum of the weights: 0.998
# Weights for the portfolio at the period 20:
#  {'ASML': 0.014, 'MC.PA': 0.017, 'NVS': 0.047, 'CFR.SW': -0.042, 'RI.PA': 0.032, '6S=F': 0.874, 'ADDYY': 0.023, 'KNEBV.HE': -0.006, 'PUB.PA': 0.069, 'COLO-B.CO': -0.0, 'SHB-A.ST': -0.04, 'HNR1.DE': -0.013, 'QGEN': -0.001, 'TRN.MI': 0.032, 'TELIA.ST': -0.003, 'RAND.AS': 0.017, 'JMT.LS': -0.033, 'LI.PA': -0.02, 'DIE.BR': 0.033}
# Sum of the weights: 1.0

# %%
pf.plot_weights(weights_tc[6])

# %% [markdown]
# The weights between the two methods are differents that implies that the transactions costs are taken into account.

# %% [markdown]
# # 5. Computes the returns and comparing with the MSCI EUROPE

# %% [markdown]
# For each period we will know compute the return and compare this return with the return found for the MSCI EUROPE with the same period. In this exercice we will not use directly dfs because dfs doesn't take into account that some asset can be selected by using the fact that we use the weight of the previous period.

# %%
# All the periods
periods = pf.dynamic_df(rends,period_per_year=4)

# %%
# We do not work with the first period because it is the training period for the first wieghts
for i in list(periods.keys())[1:]:
    # This is how we will acces the dates of each period
    print(f"Begining of the period: {periods[i].index[0]}\nEnd of the period: {periods[i].index[-1]}\n")
# Out:
# Begining of the period: 2005-04-04 00:00:00
# End of the period: 2005-06-30 00:00:00
#
# Begining of the period: 2005-07-01 00:00:00
# End of the period: 2005-09-29 00:00:00
#
# Begining of the period: 2005-09-30 00:00:00
# End of the period: 2005-12-28 00:00:00
#
# Begining of the period: 2005-12-29 00:00:00
# End of the period: 2006-03-29 00:00:00
#
# Begining of the period: 2006-03-30 00:00:00
# End of the period: 2006-06-27 00:00:00
#
# Begining of the period: 2006-06-28 00:00:00
# End of the period: 2006-09-25 00:00:00
#
# Begining of the period: 2006-09-26 00:00:00
# End of the period: 2006-12-25 00:00:00
#
# Begining of the period: 2006-12-26 00:00:00
# End of the period: 2007-03-23 00:00:00
#
# Begining of the period: 2007-03-26 00:00:00
# End of the period: 2007-06-25 00:00:00
#
# Begining of the period: 2007-06-26 00:00:00
# End of the period: 2007-09-21 00:00:00
#
# Begining of the period: 2007-09-24 00:00:00
# End of the period: 2007-12-21 00:00:00
#
# Begining of the period: 2007-12-24 00:00:00
# End of the period: 2008-03-25 00:00:00
#
# Begining of the period: 2008-03-26 00:00:00
# End of the period: 2008-06-23 00:00:00
#
# Begining of the period: 2008-06-24 00:00:00
# End of the period: 2008-09-22 00:00:00
#
# Begining of the period: 2008-09-23 00:00:00
# End of the period: 2008-12-19 00:00:00
#
# Begining of the period: 2008-12-22 00:00:00
# End of the period: 2009-03-24 00:00:00
#
# Begining of the period: 2009-03-25 00:00:00
# End of the period: 2009-06-23 00:00:00
#
# Begining of the period: 2009-06-24 00:00:00
# End of the period: 2009-09-21 00:00:00
#
# Begining of the period: 2009-09-22 00:00:00
# End of the period: 2009-12-21 00:00:00
#
# Begining of the period: 2009-12-22 00:00:00
# End of the period: 2010-03-23 00:00:00
#
# Begining of the period: 2010-03-24 00:00:00
# End of the period: 2010-06-23 00:00:00
#
# Begining of the period: 2010-06-24 00:00:00
# End of the period: 2010-09-21 00:00:00
#
# Begining of the period: 2010-09-22 00:00:00
# End of the period: 2010-12-21 00:00:00
#
# Begining of the period: 2010-12-22 00:00:00
# End of the period: 2011-03-21 00:00:00
#
# Begining of the period: 2011-03-22 00:00:00
# End of the period: 2011-06-20 00:00:00
#
# Begining of the period: 2011-06-21 00:00:00
# End of the period: 2011-09-19 00:00:00
#
# Begining of the period: 2011-09-20 00:00:00
# End of the period: 2011-12-16 00:00:00
#
# Begining of the period: 2011-12-19 00:00:00
# End of the period: 2012-03-16 00:00:00
#
# Begining of the period: 2012-03-19 00:00:00
# End of the period: 2012-06-15 00:00:00
#
# Begining of the period: 2012-06-18 00:00:00
# End of the period: 2012-09-13 00:00:00
#
# Begining of the period: 2012-09-14 00:00:00
# End of the period: 2012-12-13 00:00:00
#
# Begining of the period: 2012-12-14 00:00:00
# End of the period: 2013-03-15 00:00:00
#
# Begining of the period: 2013-03-18 00:00:00
# End of the period: 2013-06-17 00:00:00
#
# Begining of the period: 2013-06-18 00:00:00
# End of the period: 2013-09-13 00:00:00
#
# Begining of the period: 2013-09-16 00:00:00
# End of the period: 2013-12-13 00:00:00
#
# Begining of the period: 2013-12-16 00:00:00
# End of the period: 2014-03-17 00:00:00
#
# Begining of the period: 2014-03-18 00:00:00
# End of the period: 2014-06-16 00:00:00
#
# Begining of the period: 2014-06-17 00:00:00
# End of the period: 2014-09-15 00:00:00
#
# Begining of the period: 2014-09-16 00:00:00
# End of the period: 2014-12-12 00:00:00
#
# Begining of the period: 2014-12-15 00:00:00
# End of the period: 2015-03-17 00:00:00
#
# Begining of the period: 2015-03-18 00:00:00
# End of the period: 2015-06-16 00:00:00
#
# Begining of the period: 2015-06-17 00:00:00
# End of the period: 2015-09-14 00:00:00
#
# Begining of the period: 2015-09-15 00:00:00
# End of the period: 2015-12-14 00:00:00
#
# Begining of the period: 2015-12-15 00:00:00
# End of the period: 2016-03-14 00:00:00
#
# Begining of the period: 2016-03-15 00:00:00
# End of the period: 2016-06-14 00:00:00
#
# Begining of the period: 2016-06-15 00:00:00
# End of the period: 2016-09-12 00:00:00
#
# Begining of the period: 2016-09-13 00:00:00
# End of the period: 2016-12-12 00:00:00
#
# Begining of the period: 2016-12-13 00:00:00
# End of the period: 2017-03-10 00:00:00
#
# Begining of the period: 2017-03-13 00:00:00
# End of the period: 2017-06-09 00:00:00
#
# Begining of the period: 2017-06-12 00:00:00
# End of the period: 2017-09-08 00:00:00
#
# Begining of the period: 2017-09-11 00:00:00
# End of the period: 2017-12-07 00:00:00
#
# Begining of the period: 2017-12-08 00:00:00
# End of the period: 2018-03-09 00:00:00
#
# Begining of the period: 2018-03-12 00:00:00
# End of the period: 2018-06-08 00:00:00
#
# Begining of the period: 2018-06-11 00:00:00
# End of the period: 2018-09-06 00:00:00
#
# Begining of the period: 2018-09-07 00:00:00
# End of the period: 2018-12-06 00:00:00
#
# Begining of the period: 2018-12-07 00:00:00
# End of the period: 2019-03-08 00:00:00
#
# Begining of the period: 2019-03-11 00:00:00
# End of the period: 2019-06-10 00:00:00
#
# Begining of the period: 2019-06-11 00:00:00
# End of the period: 2019-09-06 00:00:00
#
# Begining of the period: 2019-09-09 00:00:00
# End of the period: 2019-12-06 00:00:00
#
# Begining of the period: 2019-12-09 00:00:00
# End of the period: 2020-03-06 00:00:00
#
# Begining of the period: 2020-03-09 00:00:00
# End of the period: 2020-06-05 00:00:00
#
# Begining of the period: 2020-06-08 00:00:00
# End of the period: 2020-09-04 00:00:00
#
# Begining of the period: 2020-09-07 00:00:00
# End of the period: 2020-12-03 00:00:00
#
# Begining of the period: 2020-12-04 00:00:00
# End of the period: 2021-03-08 00:00:00
#
# Begining of the period: 2021-03-09 00:00:00
# End of the period: 2021-06-07 00:00:00
#
# Begining of the period: 2021-06-08 00:00:00
# End of the period: 2021-09-03 00:00:00
#
# Begining of the period: 2021-09-06 00:00:00
# End of the period: 2021-12-03 00:00:00
#
# Begining of the period: 2021-12-06 00:00:00
# End of the period: 2022-03-03 00:00:00
#
# Begining of the period: 2022-03-04 00:00:00
# End of the period: 2022-06-03 00:00:00
#
# Begining of the period: 2022-06-06 00:00:00
# End of the period: 2022-09-01 00:00:00
#
# Begining of the period: 2022-09-02 00:00:00
# End of the period: 2022-12-01 00:00:00

# %%
weights_tc = {}
returns_tc = {}
vol_tc = {}
tri = 1
year = 0
for i in list(periods.keys())[1:]:
    rends_period = rends.loc[periods[i].index[0]:periods[i].index[-1]]
    # We calculate the weights of the portfolio
    if i == 2:
        w,r,v = pf.opt_mean_variance_tc(rends=periods[i-1],last_prices=prices[periods[i-1].columns].loc[periods[i-1].index[-1]],cov=periods[i-1].cov(),obj_rend=0.10)
    else:
        w,r,v = pf.opt_mean_variance_tc(rends=periods[i-1],last_prices=prices[periods[i-1].columns].loc[periods[i-1].index[-1]],last_weights=last_w,cov=periods[i-1].cov(),obj_rend=0.10)
    rends_period = rends_period[w.keys()]
    npw = np.array(list(w.values()))
    last_w  = w
    weights_tc[f"Q{tri%4+1}-{2005+year}"] = w
    returns_tc[f"Q{tri%4+1}-{2005+year}"] = pf.portfolio_rend(npw,rends_period)
    vol_tc[f"Q{tri%4+1}-{2005+year}"] = pf.portfolio_vol(npw,rends_period.cov())
    tri += 1
    if tri%4 == 0:
        year += 1

# %%
weights_tc
# Out:
# {'Q2-2005': {'ASML': -0.009,
#   'MC.PA': 0.023,
#   'ABB': 0.08,
#   'RMS.PA': 0.121,
#   'KER.PA': 0.153,
#   'ISP.MI': -0.043,
#   'CAP.PA': 0.005,
#   'IDEXF': 0.123,
#   'SAMPO.HE': 0.015,
#   'ADDYY': 0.114,
#   'PUB.PA': 0.183,
#   'KBC.BR': -0.135,
#   'HNR1.DE': -0.059,
#   'QGEN': -0.006,
#   'EBS.VI': 0.114,
#   'RDFN': 0.118,
#   'TELIA.ST': -0.044,
#   'RAND.AS': -0.009,
#   'JMT.LS': -0.025,
#   'WFDRX': 0.107,
#   'MB.MI': 0.072,
#   'ATL.MI': -0.007,
#   'LI.PA': 0.029,
#   'BOL.PA': -0.088,
#   'DIE.BR': -0.092,
#   'GFC.PA': 0.054,
#   'FR.PA': 0.04,
#   'LBGUF': 0.095,
#   'COV.PA': 0.004,
#   'MF.PA': 0.065},
#  'Q3-2005': {'ASML': -0.011,
#   'MC.PA': 0.004,
#   'NVS': -0.005,
#   'SAP': 0.007,
#   'CFR.SW': 0.012,
#   'ABB': 0.007,
#   'RMS.PA': 0.009,
#   'KER.PA': -0.0,
#   'RI.PA': 0.015,
#   'IDEXF': -1.0,
#   '6S=F': -0.008,
#   'SAMPO.HE': 0.012,
#   'ADDYY': -0.1,
#   'G.MI': -0.024,
#   'KNEBV.HE': -0.002,
#   'PUB.PA': -0.032,
#   'COLO-B.CO': 0.005,
#   'HNR1.DE': -0.015,
#   'QGEN': -0.005,
#   'TRN.MI': 0.004,
#   'EBS.VI': -0.004,
#   'RDFN': -0.444,
#   'SIG': -0.014,
#   'VIV.PA': 0.014,
#   'PNDORA.CO': 0.917,
#   'WFDRX': 0.591,
#   'MB.MI': 0.011,
#   'ATL.MI': -0.007,
#   'LI.PA': 0.021,
#   'BOL.PA': 0.013,
#   'GFC.PA': 0.009,
#   'SECU-B.ST': 0.004,
#   'FR.PA': -0.011,
#   'LBGUF': 1.0,
#   'COV.PA': 0.011,
#   'MF.PA': 0.017},
#  'Q4-2005': {'ASML': -0.054,
#   'MC.PA': -0.091,
#   'NVS': 0.041,
#   'SAP': 0.033,
#   'CFR.SW': -0.07,
#   'ABB': 0.028,
#   'RMS.PA': -0.002,
#   'KER.PA': 0.017,
#   'RI.PA': -0.035,
#   'ISP.MI': 0.001,
#   'CAP.PA': -0.028,
#   'IDEXF': 0.509,
#   'SAMPO.HE': 0.04,
#   'ADDYY': 0.294,
#   'G.MI': 0.091,
#   'KNEBV.HE': 0.062,
#   'PUB.PA': -0.019,
#   'COLO-B.CO': 0.037,
#   'SHB-A.ST': -0.013,
#   'SCMN.SW': 0.134,
#   'KBC.BR': 0.165,
#   'QGEN': 0.05,
#   'TRN.MI': 0.054,
#   'EBS.VI': 0.047,
#   'GBLC.CN': -0.001,
#   'RDFN': 0.374,
#   'RAND.AS': -0.001,
#   'VIV.PA': -0.016,
#   'JMT.LS': 0.112,
#   'WFDRX': 0.134,
#   'MB.MI': -0.041,
#   'LI.PA': 0.063,
#   'BOL.PA': 0.03,
#   'DIE.BR': -0.032,
#   'GFC.PA': 0.057,
#   'LBGUF': -1.0,
#   'COV.PA': 0.024,
#   'MF.PA': 0.008},
#  'Q1-2006': {'ASML': -0.001,
#   'MC.PA': -0.001,
#   'NVS': 0.006,
#   'SAP': 0.011,
#   'CFR.SW': -0.002,
#   'ABB': -0.001,
#   'RMS.PA': 0.012,
#   'KER.PA': 0.009,
#   'RI.PA': -0.001,
#   'ISP.MI': 0.022,
#   'CAP.PA': -0.02,
#   'IDEXF': -1.0,
#   'SAMPO.HE': -0.007,
#   'ADDYY': -0.118,
#   'G.MI': -0.001,
#   'KNEBV.HE': -0.001,
#   'PUB.PA': 0.009,
#   'COLO-B.CO': 0.002,
#   'SHB-A.ST': -0.004,
#   'KBC.BR': 0.009,
#   'HNR1.DE': 0.006,
#   'EBS.VI': 0.01,
#   'RDFN': -0.458,
#   'TELIA.ST': 0.01,
#   'RAND.AS': 0.01,
#   'SIG': -0.004,
#   'PNDORA.CO': 0.939,
#   'JMT.LS': 0.02,
#   'WFDRX': 0.565,
#   'DIE.BR': 0.004,
#   'SECU-B.ST': -0.007,
#   'LBGUF': 0.994,
#   'MF.PA': -0.013},
#  'Q2-2006': {'MC.PA': 0.011,
#   'NVS': 0.185,
#   'SAP': 0.011,
#   'CFR.SW': 0.078,
#   'ABB': -0.063,
#   'RMS.PA': 0.15,
#   'KER.PA': 0.017,
#   'RI.PA': 0.001,
#   'ISP.MI': -0.017,
#   'CAP.PA': -0.04,
#   'SAMPO.HE': 0.066,
#   'G.MI': -0.079,
#   'KNEBV.HE': 0.052,
#   'PUB.PA': 0.183,
#   'COLO-B.CO': 0.008,
#   'SHB-A.ST': -0.028,
#   'SCMN.SW': 0.11,
#   'KBC.BR': -0.14,
#   'HNR1.DE': 0.035,
#   'QGEN': -0.005,
#   'TRN.MI': 0.171,
#   'GBLC.CN': -0.004,
#   'TELIA.ST': 0.057,
#   'RAND.AS': -0.048,
#   'SIG': -0.02,
#   'VIV.PA': -0.063,
#   'JMT.LS': 0.184,
#   'MB.MI': 0.078,
#   'ATL.MI': 0.05,
#   'LI.PA': -0.013,
#   'BOL.PA': -0.074,
#   'DIE.BR': -0.031,
#   'GFC.PA': 0.052,
#   'SECU-B.ST': -0.018,
#   'FR.PA': 0.143,
#   'COV.PA': 0.025,
#   'MF.PA': -0.022},
#  'Q3-2006': {'6S=F': -0.005,
#   'GBLC.CN': 0.011,
#   'PNDORA.CO': 0.938,
#   'ATL.MI': 0.056},
#  'Q4-2006': {'ASML': -0.013,
#   'MC.PA': -0.057,
#   'NVS': 0.232,
#   'CFR.SW': -0.101,
#   'ABB': -0.009,
#   'RMS.PA': 0.057,
#   'KER.PA': 0.024,
#   'RI.PA': -0.011,
#   'ISP.MI': -0.061,
#   'SAMPO.HE': -0.022,
#   'G.MI': 0.179,
#   'KNEBV.HE': 0.001,
#   'PUB.PA': 0.146,
#   'COLO-B.CO': 0.092,
#   'SHB-A.ST': 0.047,
#   'SCMN.SW': 0.269,
#   'KBC.BR': -0.097,
#   'HNR1.DE': -0.15,
#   'QGEN': 0.03,
#   'TRN.MI': 0.08,
#   'EBS.VI': -0.026,
#   'TELIA.ST': -0.054,
#   'SIG': 0.01,
#   'VIV.PA': -0.119,
#   'JMT.LS': 0.248,
#   'MB.MI': -0.01,
#   'ATL.MI': 0.142,
#   'LI.PA': -0.172,
#   'BOL.PA': -0.006,
#   'DIE.BR': 0.02,
#   'GFC.PA': 0.267,
#   'FR.PA': -0.016,
#   'COV.PA': 0.088,
#   'MF.PA': -0.009},
#  'Q1-2007': {'ASML': -0.006,
#   'MC.PA': -0.046,
#   'SAP': -0.011,
#   'CFR.SW': 0.001,
#   'ABB': 0.024,
#   'RMS.PA': 0.009,
#   'KER.PA': -0.01,
#   'RI.PA': 0.003,
#   'ISP.MI': -0.006,
#   'CAP.PA': 0.013,
#   'SAMPO.HE': 0.006,
#   'ADDYY': -0.001,
#   'LR.PA': -0.012,
#   'G.MI': 0.021,
#   'KNEBV.HE': 0.009,
#   'PUB.PA': 0.007,
#   'COLO-B.CO': 0.006,
#   'SHB-A.ST': -0.016,
#   'SCMN.SW': 0.066,
#   'KBC.BR': 0.005,
#   'HNR1.DE': -0.01,
#   'TRN.MI': 0.005,
#   'EBS.VI': 0.005,
#   'GBLC.CN': 0.002,
#   'TELIA.ST': -0.001,
#   'RAND.AS': 0.004,
#   'SIG': 0.004,
#   'VIV.PA': -0.016,
#   'PNDORA.CO': 0.892,
#   'JMT.LS': 0.014,
#   'MB.MI': -0.013,
#   'LI.PA': 0.007,
#   'BOL.PA': -0.013,
#   'DIE.BR': 0.026,
#   'GFC.PA': 0.021,
#   'FR.PA': -0.012,
#   'COV.PA': 0.023,
#   'MF.PA': 0.001},
#  'Q2-2007': {'ASML': -0.007,
#   'MC.PA': 0.012,
#   'RMS.PA': 0.031,
#   'KER.PA': -0.013,
#   'ISP.MI': -0.02,
#   'CAP.PA': -0.007,
#   'SAMPO.HE': 0.03,
#   'ADDYY': -0.019,
#   'LR.PA': 0.004,
#   'KNEBV.HE': -0.016,
#   'PUB.PA': 0.024,
#   'KBC.BR': -0.033,
#   'QGEN': 0.022,
#   'TRN.MI': -0.012,
#   'EBS.VI': 0.02,
#   'TELIA.ST': -0.019,
#   'RAND.AS': -0.0,
#   'SIG': 0.019,
#   'VIV.PA': -0.006,
#   'PNDORA.CO': 0.946,
#   'JMT.LS': 0.001,
#   'ATL.MI': 0.004,
#   'LI.PA': -0.015,
#   'DIE.BR': -0.004,
#   'GFC.PA': 0.014,
#   'FR.PA': 0.037,
#   'COV.PA': 0.0,
#   'MF.PA': 0.006},
#  'Q3-2007': {'ASML': 0.012,
#   'MC.PA': -0.016,
#   'SAP': -0.012,
#   'CFR.SW': -0.063,
#   'ABB': 0.077,
#   'KER.PA': -0.008,
#   'RI.PA': -0.008,
#   'ADDYY': 0.016,
#   'LR.PA': -0.013,
#   'G.MI': 0.009,
#   'KNEBV.HE': 0.015,
#   'KBC.BR': -0.006,
#   'HNR1.DE': -0.015,
#   'GBLC.CN': 0.012,
#   'VIV.PA': 0.036,
#   'PNDORA.CO': 0.925,
#   'JMT.LS': 0.007,
#   'MB.MI': -0.006,
#   'ATL.MI': -0.007,
#   'BOL.PA': -0.0,
#   'DIE.BR': 0.017,
#   'MF.PA': 0.03},
#  'Q4-2007': {'ASML': 0.018,
#   'SAP': 0.053,
#   'CFR.SW': -0.053,
#   'ABB': -0.025,
#   'KER.PA': 0.065,
#   '6S=F': 0.793,
#   'ADDYY': -0.013,
#   'G.MI': 0.01,
#   'KNEBV.HE': 0.011,
#   'COLO-B.CO': 0.029,
#   'SHB-A.ST': 0.033,
#   'SCMN.SW': 0.016,
#   'TELIA.ST': 0.063},
#  'Q1-2008': {'CFR.SW': 0.1,
#   'ABB': -0.078,
#   'RMS.PA': -0.15,
#   'RI.PA': 0.208,
#   'ADDYY': 0.06,
#   'G.MI': 0.166,
#   'SHB-A.ST': 0.137,
#   'KBC.BR': -0.012,
#   'QGEN': -0.143,
#   'TRN.MI': 0.142,
#   'BVI.PA': -0.005,
#   'TELIA.ST': 0.04,
#   'VIV.PA': 0.206,
#   'JMT.LS': -0.028,
#   'ATL.MI': 0.188,
#   'BOL.PA': 0.169,
#   'SECU-B.ST': 0.001},
#  'Q2-2008': {'6S=F': 0.04,
#   'KNEBV.HE': 0.018,
#   'HNR1.DE': -0.008,
#   'GBLC.CN': 0.015,
#   'PNDORA.CO': 0.902,
#   'LI.PA': 0.023,
#   'BOL.PA': -0.026,
#   'COV.PA': 0.035},
#  'Q3-2008': {'ASML': -0.005,
#   'NVS': -0.012,
#   'SAP': -0.014,
#   'CFR.SW': -0.036,
#   'ABB': 0.06,
#   'RMS.PA': 0.025,
#   'CAP.PA': 0.012,
#   'IDEXF': -1.0,
#   'ADDYY': -0.03,
#   'COLO-B.CO': 0.002,
#   'SCMN.SW': 0.004,
#   'TRN.MI': -0.009,
#   'EBS.VI': -0.008,
#   'GBLC.CN': -0.001,
#   'RDFN': -1.0,
#   'BVI.PA': 0.013,
#   'TELIA.ST': 0.006,
#   'PNDORA.CO': 0.982,
#   'WFDRX': 1.0,
#   'ATL.MI': 0.009,
#   'LBGUF': 1.0},
#  'Q4-2008': {'NVS': 0.05,
#   'SAP': -0.065,
#   'RMS.PA': -0.01,
#   'ISP.MI': -0.112,
#   'IDEXF': 1.0,
#   '6S=F': 0.512,
#   'SAMPO.HE': 0.132,
#   'PUB.PA': 0.15,
#   'SHB-A.ST': -0.095,
#   'SCMN.SW': 0.393,
#   'QGEN': -0.004,
#   'RDFN': 0.125,
#   'SIG': -0.05,
#   'JMT.LS': 0.022,
#   'WFDRX': -0.145,
#   'DIE.BR': 0.092,
#   'SECU-B.ST': 0.024,
#   'FR.PA': -0.02,
#   'LBGUF': -1.0},
#  'Q1-2009': {'IDEXF': -1.0,
#   '6S=F': -0.244,
#   'SCMN.SW': 0.13,
#   'RDFN': -0.693,
#   'PNDORA.CO': 0.807,
#   'WFDRX': 1.0,
#   'LBGUF': 1.0},
#  'Q2-2009': {'ASML': -0.023,
#   'MC.PA': 0.01,
#   'SAP': 0.018,
#   'ABB': 0.007,
#   'KER.PA': -0.013,
#   'IDEXF': -1.0,
#   '6S=F': -0.01,
#   'LR.PA': -0.014,
#   'KNEBV.HE': 0.001,
#   'PUB.PA': -0.004,
#   'HNR1.DE': 0.005,
#   'QGEN': -0.005,
#   'TRN.MI': 0.004,
#   'GBLC.CN': 0.004,
#   'RDFN': -0.954,
#   'SIG': 0.009,
#   'PNDORA.CO': 0.921,
#   'WFDRX': 1.0,
#   'DIE.BR': 0.032,
#   'IDVA.SG': 0.009,
#   'FR.PA': 0.005,
#   'LBGUF': 1.0},
#  'Q3-2009': {'ASML': -0.0,
#   'MC.PA': -0.002,
#   'NVS': 0.003,
#   'SAP': -0.005,
#   'CFR.SW': -0.018,
#   'ABB': 0.004,
#   'RMS.PA': -0.012,
#   'KER.PA': 0.002,
#   'RI.PA': -0.012,
#   'ISP.MI': -0.001,
#   'CAP.PA': -0.016,
#   '6S=F': 0.022,
#   'SAMPO.HE': 0.016,
#   'ADDYY': 0.007,
#   'LR.PA': -0.012,
#   'G.MI': -0.015,
#   'KNEBV.HE': 0.021,
#   'CABK.MC': 0.009,
#   'PUB.PA': 0.004,
#   'COLO-B.CO': -0.013,
#   'SHB-A.ST': -0.003,
#   'SCMN.SW': 0.012,
#   'HNR1.DE': 0.005,
#   'QGEN': 0.007,
#   'EBS.VI': -0.002,
#   'GBLC.CN': 0.001,
#   'BVI.PA': 0.003,
#   'TELIA.ST': -0.015,
#   'RAND.AS': 0.018,
#   'SIG': 0.004,
#   'PNDORA.CO': 0.973,
#   'JMT.LS': 0.002,
#   'MB.MI': 0.005,
#   'ATL.MI': 0.005,
#   'LI.PA': 0.004,
#   'BOL.PA': 0.009,
#   'DIE.BR': -0.005,
#   'GFC.PA': 0.001,
#   'SECU-B.ST': -0.006,
#   'FR.PA': 0.0,
#   'COV.PA': 0.004,
#   'MF.PA': -0.003},
#  'Q4-2009': {'ASML': -0.005,
#   'MC.PA': -0.024,
#   'NVS': 0.017,
#   'SAP': 0.019,
#   'CFR.SW': 0.01,
#   'ABB': -0.0,
#   'RMS.PA': 0.014,
#   'KER.PA': 0.02,
#   'RI.PA': 0.016,
#   'ISP.MI': 0.01,
#   'CAP.PA': -0.012,
#   'SAMPO.HE': -0.007,
#   'ADDYY': -0.017,
#   'LR.PA': 0.007,
#   'G.MI': -0.029,
#   'KNEBV.HE': 0.005,
#   'CABK.MC': -0.003,
#   'PUB.PA': 0.003,
#   'COLO-B.CO': -0.002,
#   'SHB-A.ST': 0.004,
#   'SCMN.SW': 0.033,
#   'KBC.BR': 0.003,
#   'HNR1.DE': -0.01,
#   'QGEN': 0.015,
#   'TRN.MI': 0.006,
#   'EBS.VI': -0.001,
#   'BVI.PA': -0.006,
#   'TELIA.ST': -0.013,
#   'RAND.AS': 0.014,
#   'SIG': 0.004,
#   'VIV.PA': 0.005,
#   'PNDORA.CO': 0.941,
#   'JMT.LS': -0.009,
#   'MB.MI': -0.009,
#   'ATL.MI': 0.014,
#   'LI.PA': 0.008,
#   'BOL.PA': -0.004,
#   'DIE.BR': -0.001,
#   'GFC.PA': 0.006,
#   'SECU-B.ST': -0.017,
#   'FR.PA': -0.009,
#   'COV.PA': -0.003,
#   'MF.PA': 0.009},
#  'Q1-2010': {'ASML': -0.0,
#   'MC.PA': 0.047,
#   'NVS': 0.034,
#   'CFR.SW': -0.025,
#   'RI.PA': 0.004,
#   'ISP.MI': -0.037,
#   'IDEXF': 0.026,
#   '6S=F': 0.776,
#   'ADDYY': 0.029,
#   'LR.PA': -0.001,
#   'G.MI': 0.055,
#   'KNEBV.HE': -0.046,
#   'PUB.PA': 0.017,
#   'COLO-B.CO': -0.007,
#   'SHB-A.ST': -0.021,
#   'SCMN.SW': 0.014,
#   'HNR1.DE': 0.001,
#   'QGEN': 0.007,
#   'TRN.MI': 0.047,
#   'GBLC.CN': -0.007,
#   'RDFN': 0.024,
#   'TELIA.ST': 0.019,
#   'RAND.AS': 0.03,
#   'SIG': 0.029,
#   'VIV.PA': -0.041,
#   'JMT.LS': -0.017,
#   'WFDRX': 0.019,
#   'ATL.MI': 0.011,
#   'LI.PA': -0.006,
#   'DIE.BR': 0.03,
#   'SECU-B.ST': 0.01,
#   'FR.PA': -0.02,
#   'LBGUF': 0.014,
#   'MF.PA': -0.017},
#  'Q2-2010': {'ASML': 0.002,
#   'MC.PA': 0.005,
#   'NVS': -0.019,
#   'SAP': -0.0,
#   'CFR.SW': 0.015,
#   'ABB': 0.007,
#   'RMS.PA': -0.008,
#   'KER.PA': 0.009,
#   'RI.PA': -0.031,
#   'CAP.PA': 0.006,
#   'IDEXF': 0.019,
#   '6S=F': -0.061,
#   'SAMPO.HE': 0.009,
#   'ADDYY': -0.013,
#   'LR.PA': 0.012,
#   'KNEBV.HE': 0.013,
#   'CABK.MC': -0.005,
#   'PUB.PA': 0.011,
#   'COLO-B.CO': 0.006,
#   'SHB-A.ST': -0.0,
#   'SCMN.SW': 0.016,
#   'KBC.BR': 0.002,
#   'HNR1.DE': 0.006,
#   'QGEN': 0.009,
#   'TRN.MI': 0.03,
#   'EBS.VI': 0.004,
#   'RDFN': 0.021,
#   'BVI.PA': -0.004,
#   'TELIA.ST': -0.015,
#   'RAND.AS': -0.012,
#   'SIG': -0.003,
#   'PNDORA.CO': 0.941,
#   'JMT.LS': -0.018,
#   'WFDRX': 0.021,
#   'LI.PA': -0.011,
#   'BOL.PA': 0.02,
#   'DIE.BR': 0.008,
#   'GFC.PA': -0.0,
#   'SECU-B.ST': -0.0,
#   'IDVA.SG': 0.0,
#   'FR.PA': -0.002,
#   'LBGUF': 0.022,
#   'COV.PA': -0.009,
#   'MF.PA': -0.004},
#  'Q3-2010': {'MC.PA': 0.086,
#   'SAP': 0.245,
#   'CFR.SW': -0.134,
#   'RMS.PA': 0.046,
#   'KER.PA': -0.093,
#   'RI.PA': 0.062,
#   'CAP.PA': -0.013,
#   'IDEXF': 1.0,
#   '6S=F': 0.794,
#   'AMS.MC': -0.072,
#   'ADDYY': -0.046,
#   'LR.PA': 0.002,
#   'KNEBV.HE': 0.026,
#   'PUB.PA': -0.086,
#   'COLO-B.CO': 0.073,
#   'SCMN.SW': -0.036,
#   'BNR.DE': 0.012,
#   'RDFN': 0.511,
#   'BVI.PA': -0.108,
#   'RAND.AS': 0.013,
#   'SIG': 0.03,
#   'WFDRX': -0.403,
#   'BOL.PA': -0.029,
#   'DIE.BR': 0.017,
#   'IDVA.SG': -0.037,
#   'LBGUF': -1.0,
#   'MF.PA': 0.139},
#  'Q4-2010': {'MC.PA': 0.017,
#   'NVS': -0.159,
#   'SAP': -0.028,
#   'CFR.SW': -0.094,
#   'ABB': -0.095,
#   'RMS.PA': -0.053,
#   'KER.PA': 0.113,
#   'ISP.MI': -0.007,
#   '6S=F': 0.409,
#   'AMS.MC': 0.059,
#   'SAMPO.HE': 0.099,
#   'ADDYY': 0.025,
#   'KNEBV.HE': -0.004,
#   'CABK.MC': -0.064,
#   'COLO-B.CO': 0.182,
#   'SHB-A.ST': -0.014,
#   'SCMN.SW': -0.012,
#   'KBC.BR': 0.013,
#   'BNR.DE': 0.008,
#   'TRN.MI': 0.389,
#   'EBS.VI': -0.007,
#   'GBLC.CN': -0.004,
#   'BVI.PA': 0.118,
#   'TELIA.ST': 0.139,
#   'VIV.PA': -0.174,
#   'JMT.LS': 0.045,
#   'MB.MI': -0.015,
#   'ATL.MI': 0.015,
#   'LI.PA': -0.006,
#   'BOL.PA': 0.13,
#   'DIE.BR': -0.087,
#   'GFC.PA': 0.036,
#   'SECU-B.ST': -0.055,
#   'IDVA.SG': -0.012,
#   'FR.PA': -0.008,
#   'COV.PA': 0.046,
#   'MF.PA': 0.054},
#  'Q1-2011': {'ASML': -0.033,
#   'MC.PA': -0.149,
#   'NVS': 0.021,
#   'SAP': -0.127,
#   'CFR.SW': -0.095,
#   'ABB': 0.041,
#   'KER.PA': 0.181,
#   'RI.PA': -0.009,
#   '6S=F': 0.3,
#   'AMS.MC': -0.022,
#   'SAMPO.HE': 0.036,
#   'ADDYY': -0.089,
#   'LR.PA': 0.118,
#   'KNEBV.HE': -0.117,
#   'CABK.MC': 0.042,
#   'PUB.PA': 0.168,
#   'COLO-B.CO': 0.03,
#   'SHB-A.ST': 0.094,
#   'SCMN.SW': 0.099,
#   'HNR1.DE': 0.013,
#   'QGEN': -0.083,
#   'BNR.DE': -0.03,
#   'TRN.MI': 0.13,
#   'EBS.VI': -0.019,
#   'BVI.PA': 0.086,
#   'TELIA.ST': 0.262,
#   'RAND.AS': 0.057,
#   'SIG': 0.06,
#   'VIV.PA': 0.01,
#   'PNDORA.CO': 0.084,
#   'JMT.LS': -0.032,
#   'MB.MI': -0.052,
#   'BOL.PA': 0.18,
#   'DIE.BR': -0.063,
#   'GFC.PA': -0.003,
#   'SECU-B.ST': -0.059,
#   'IDVA.SG': 0.017,
#   'FR.PA': 0.036,
#   'MF.PA': -0.081},
#  'Q2-2011': {'ASML': -0.021,
#   'SAP': 0.065,
#   'ABB': 0.035,
#   'ISP.MI': -0.138,
#   'CAP.PA': -0.088,
#   'SAMPO.HE': 0.005,
#   'CABK.MC': -0.019,
#   'KBC.BR': 0.008,
#   'TRN.MI': 0.589,
#   'EBS.VI': 0.118,
#   'GBLC.CN': 0.016,
#   'MB.MI': 0.12,
#   'ATL.MI': 0.232,
#   'LI.PA': 0.103,
#   'BOL.PA': 0.143,
#   'DIE.BR': -0.025,
#   'GFC.PA': -0.105,
#   'COV.PA': 0.106,
#   'MF.PA': -0.141},
#  'Q3-2011': {'MC.PA': 0.026,
#   'NVS': -0.121,
#   'SAP': 0.017,
#   'CFR.SW': -0.081,
#   'ABB': -0.042,
#   'RMS.PA': 0.011,
#   'KER.PA': -0.133,
#   'RI.PA': 0.117,
#   '6S=F': 0.399,
#   'AMS.MC': 0.08,
#   'ADDYY': -0.024,
#   'KNEBV.HE': 0.218,
#   'PUB.PA': -0.018,
#   'COLO-B.CO': 0.048,
#   'SCMN.SW': 0.036,
#   'BNR.DE': 0.058,
#   'BVI.PA': 0.267,
#   'JMT.LS': 0.027,
#   'LI.PA': 0.116,
#   'BOL.PA': 0.151,
#   'DIE.BR': 0.043,
#   'GFC.PA': -0.004,
#   'FR.PA': -0.087,
#   'MF.PA': -0.106},
#  'Q4-2011': {'ASML': -0.144,
#   'RMS.PA': -0.034,
#   'IDEXF': 1.0,
#   'COLO-B.CO': 0.157,
#   'GBLC.CN': 0.002,
#   'RDFN': 0.636,
#   'WFDRX': -0.038,
#   'BOL.PA': 0.191,
#   'LBGUF': -0.769},
#  'Q1-2012': {'ASML': 0.045,
#   'NVS': 0.084,
#   'SAP': -0.127,
#   'ABB': -0.09,
#   'RI.PA': -0.062,
#   'ISP.MI': -0.106,
#   'IDEXF': 0.987,
#   'G.MI': 0.085,
#   'KNEBV.HE': 0.027,
#   'CABK.MC': 0.161,
#   'PUB.PA': 0.005,
#   'COLO-B.CO': 0.032,
#   'SHB-A.ST': 0.101,
#   'HNR1.DE': 0.079,
#   'QGEN': 0.015,
#   'RDFN': 0.62,
#   'BVI.PA': 0.106,
#   'TELIA.ST': -0.064,
#   'SIG': -0.047,
#   'VIV.PA': -0.018,
#   'PNDORA.CO': 0.024,
#   'JMT.LS': -0.017,
#   'WFDRX': -0.058,
#   'ATL.MI': -0.077,
#   'LI.PA': 0.062,
#   'SECU-B.ST': -0.009,
#   'IDVA.SG': 0.035,
#   'LBGUF': -0.794},
#  'Q2-2012': {'ASML': 0.036,
#   'MC.PA': -0.069,
#   'SAP': -0.111,
#   'CFR.SW': 0.092,
#   'ABB': -0.172,
#   'RMS.PA': 0.017,
#   'KER.PA': 0.053,
#   'RI.PA': 0.081,
#   'ISP.MI': -0.023,
#   'CAP.PA': -0.017,
#   'IDEXF': 0.14,
#   '6S=F': 0.305,
#   'AMS.MC': 0.141,
#   'SAMPO.HE': 0.003,
#   'ADDYY': -0.19,
#   'LR.PA': -0.01,
#   'G.MI': -0.05,
#   'KNEBV.HE': -0.005,
#   'PUB.PA': -0.036,
#   'COLO-B.CO': 0.003,
#   'SHB-A.ST': 0.175,
#   'SCMN.SW': 0.236,
#   'KBC.BR': -0.001,
#   'HNR1.DE': -0.067,
#   'QGEN': 0.105,
#   'BNR.DE': -0.031,
#   'TRN.MI': 0.032,
#   'EBS.VI': -0.06,
#   'GBLC.CN': 0.0,
#   'BVI.PA': 0.067,
#   'TELIA.ST': 0.085,
#   'RAND.AS': -0.006,
#   'SIG': 0.039,
#   'PNDORA.CO': -0.012,
#   'JMT.LS': -0.046,
#   'MB.MI': 0.055,
#   'ATL.MI': -0.028,
#   'LI.PA': 0.14,
#   'BOL.PA': 0.143,
#   'DIE.BR': 0.017,
#   'GFC.PA': -0.066,
#   'SECU-B.ST': 0.057,
#   'IDVA.SG': 0.018,
#   'FR.PA': 0.017,
#   'COV.PA': 0.102,
#   'MF.PA': -0.158},
#  'Q3-2012': {'ASML': -0.065,
#   'NVS': -0.008,
#   'RMS.PA': 0.051,
#   'AMS.MC': 0.128,
#   'KNEBV.HE': 0.034,
#   'COLO-B.CO': 0.131,
#   'SCMN.SW': 0.043,
#   'HNR1.DE': 0.064,
#   'QGEN': -0.133,
#   'RDFN': 1.0,
#   'BVI.PA': -0.017,
#   'VIV.PA': -0.036,
#   'WFDRX': 0.302,
#   'BOL.PA': -0.024,
#   'LBGUF': -0.469},
#  'Q4-2012': {'ASML': -0.035,
#   'MC.PA': -0.011,
#   'NVS': 0.339,
#   'SAP': 0.043,
#   'CFR.SW': -0.064,
#   'ABB': -0.13,
#   'KER.PA': 0.059,
#   'RI.PA': 0.017,
#   'ISP.MI': -0.031,
#   'CAP.PA': -0.084,
#   'IDEXF': -0.087,
#   'AMS.MC': -0.011,
#   'SAMPO.HE': 0.408,
#   'ADDYY': -0.1,
#   'LR.PA': -0.124,
#   'G.MI': -0.081,
#   'KNEBV.HE': 0.159,
#   'CABK.MC': 0.102,
#   'PUB.PA': -0.013,
#   'COLO-B.CO': 0.001,
#   'SHB-A.ST': -0.03,
#   'SCMN.SW': 0.202,
#   'KBC.BR': -0.013,
#   'HNR1.DE': -0.09,
#   'QGEN': -0.054,
#   'BNR.DE': 0.046,
#   'TRN.MI': 0.192,
#   'EBS.VI': 0.028,
#   'BVI.PA': 0.491,
#   'TELIA.ST': -0.09,
#   'RAND.AS': 0.2,
#   'SIG': 0.076,
#   'VIV.PA': -0.025,
#   'PNDORA.CO': -0.049,
#   'MB.MI': 0.086,
#   'ATL.MI': -0.131,
#   'LI.PA': 0.271,
#   'BOL.PA': 0.028,
#   'DIE.BR': -0.085,
#   'GFC.PA': -0.044,
#   'IDVA.SG': -0.022,
#   'FR.PA': -0.003,
#   'COV.PA': -0.03,
#   'MF.PA': -0.311},
#  'Q1-2013': {'ASML': -0.022,
#   'MC.PA': 0.077,
#   'NVS': 0.146,
#   'SAP': -0.084,
#   'CFR.SW': -0.165,
#   'ABB': 0.026,
#   'RMS.PA': 0.135,
#   'KER.PA': 0.163,
#   'RI.PA': -0.008,
#   'CAP.PA': 0.001,
#   'IDEXF': 0.032,
#   'AMS.MC': 0.133,
#   'SAMPO.HE': 0.209,
#   'ADDYY': 0.015,
#   'LR.PA': -0.261,
#   'G.MI': -0.06,
#   'KNEBV.HE': -0.193,
#   'PUB.PA': 0.036,
#   'COLO-B.CO': 0.157,
#   'SCMN.SW': -0.02,
#   'KBC.BR': 0.013,
#   'HNR1.DE': 0.009,
#   'BNR.DE': -0.128,
#   'TRN.MI': 0.013,
#   'EBS.VI': -0.033,
#   'GBLC.CN': -0.005,
#   'BVI.PA': 0.202,
#   'SIG': 0.067,
#   'VIV.PA': 0.114,
#   'PNDORA.CO': -0.075,
#   'JMT.LS': -0.067,
#   'MB.MI': 0.02,
#   'ATL.MI': 0.003,
#   'LI.PA': 0.309,
#   'BOL.PA': 0.086,
#   'DIE.BR': 0.113,
#   'GFC.PA': -0.123,
#   'SECU-B.ST': 0.025,
#   'IDVA.SG': 0.226,
#   'COV.PA': -0.206,
#   'MF.PA': 0.118},
#  'Q2-2013': {'ASML': -0.037,
#   'NVS': -0.159,
#   'SAP': -0.022,
#   'CFR.SW': 0.072,
#   'ABB': -0.016,
#   'RMS.PA': 0.067,
#   'KER.PA': -0.11,
#   'RI.PA': 0.044,
#   'CAP.PA': 0.096,
#   'IDEXF': -0.091,
#   'AMS.MC': -0.028,
#   'SAMPO.HE': -0.024,
#   'ADDYY': -0.08,
#   'LR.PA': 0.021,
#   'KNEBV.HE': 0.056,
#   'CABK.MC': -0.097,
#   'PUB.PA': -0.054,
#   'COLO-B.CO': -0.002,
#   'SHB-A.ST': 0.016,
#   'SCMN.SW': -0.024,
#   'KBC.BR': 0.024,
#   'HNR1.DE': 0.064,
#   'QGEN': 0.031,
#   'BNR.DE': 0.153,
#   'TRN.MI': 0.149,
#   'EBS.VI': 0.067,
#   'RDFN': 0.247,
#   'BVI.PA': 0.015,
#   'TELIA.ST': 0.011,
#   'RAND.AS': 0.068,
#   'SIG': 0.075,
#   'PNDORA.CO': -0.062,
#   'JMT.LS': 0.083,
#   'WFDRX': 0.233,
#   'MB.MI': -0.015,
#   'LI.PA': -0.089,
#   'BOL.PA': 0.063,
#   'GFC.PA': 0.003,
#   'SECU-B.ST': 0.057,
#   'IDVA.SG': 0.056,
#   'FR.PA': -0.064,
#   'LBGUF': 0.218,
#   'COV.PA': 0.044,
#   'MF.PA': -0.058},
#  'Q3-2013': {'ASML': -0.081,
#   'NVS': 0.025,
#   'CFR.SW': -0.221,
#   'RMS.PA': 0.088,
#   'ISP.MI': 0.021,
#   'CAP.PA': 0.113,
#   'AMS.MC': 0.289,
#   'SAMPO.HE': 0.045,
#   'ADDYY': 0.204,
#   'LR.PA': 0.238,
#   'G.MI': -0.332,
#   'KNEBV.HE': -0.104,
#   'PUB.PA': 0.006,
#   'COLO-B.CO': 0.092,
#   'KBC.BR': 0.004,
#   'BNR.DE': 0.137,
#   'TRN.MI': 0.102,
#   'SIG': 0.002,
#   'PNDORA.CO': -0.03,
#   'JMT.LS': 0.022,
#   'MB.MI': 0.115,
#   'ATL.MI': 0.184,
#   'LI.PA': 0.283,
#   'BOL.PA': 0.011,
#   'GFC.PA': -0.105,
#   'FR.PA': -0.11},
#  'Q4-2013': {'ASML': -0.086,
#   'MC.PA': -0.007,
#   'NVS': -0.004,
#   'CFR.SW': -0.159,
#   'ABB': 0.021,
#   'RMS.PA': -0.024,
#   'KER.PA': 0.033,
#   'RI.PA': 0.105,
#   'ISP.MI': -0.041,
#   'CAP.PA': 0.032,
#   'IDEXF': -0.07,
#   'AMS.MC': 0.067,
#   'SAMPO.HE': 0.041,
#   'LR.PA': 0.086,
#   'G.MI': 0.052,
#   'VNA.DE': 0.06,
#   'KNEBV.HE': 0.04,
#   'CABK.MC': 0.013,
#   'PUB.PA': 0.025,
#   'SCMN.SW': 0.208,
#   'KBC.BR': -0.036,
#   'QGEN': -0.114,
#   'BNR.DE': 0.029,
#   'GBLC.CN': 0.006,
#   'RDFN': 0.218,
#   'BVI.PA': 0.054,
#   'TELIA.ST': 0.044,
#   'RAND.AS': -0.073,
#   'SIG': 0.015,
#   'VIV.PA': 0.155,
#   'PNDORA.CO': -0.038,
#   'WFDRX': 0.129,
#   'ATL.MI': -0.065,
#   'BOL.PA': -0.047,
#   'DIE.BR': 0.11,
#   'SECU-B.ST': -0.001,
#   'IDVA.SG': 0.012,
#   'FR.PA': 0.052,
#   'LBGUF': 0.211,
#   'MF.PA': -0.054},
#  'Q1-2014': {'SAP': 0.01,
#   'ABB': -0.175,
#   'ISP.MI': -0.047,
#   'CAP.PA': -0.059,
#   'IDEXF': -0.016,
#   '6S=F': 0.578,
#   'AMS.MC': 0.11,
#   'SAMPO.HE': 0.063,
#   'ADDYY': -0.046,
#   'G.MI': 0.111,
#   'CABK.MC': 0.021,
#   'PUB.PA': 0.07,
#   'COLO-B.CO': -0.001,
#   'SCMN.SW': 0.109,
#   'KBC.BR': 0.002,
#   'HNR1.DE': 0.069,
#   'QGEN': -0.003,
#   'BNR.DE': 0.088,
#   'TRN.MI': -0.004,
#   'EBS.VI': -0.009,
#   'GBLC.CN': -0.004,
#   'RAND.AS': -0.046,
#   'SIG': -0.004,
#   'VIV.PA': -0.04,
#   'PNDORA.CO': -0.04,
#   'MB.MI': 0.022,
#   'ATL.MI': 0.011,
#   'LI.PA': 0.105,
#   'BOL.PA': 0.026,
#   'GFC.PA': -0.025,
#   'FR.PA': 0.026,
#   'COV.PA': 0.027,
#   'MF.PA': 0.071},
#  'Q2-2014': {'ASML': -0.051,
#   'MC.PA': 0.027,
#   'NVS': -0.084,
#   'ABB': -0.085,
#   'RI.PA': 0.011,
#   'ISP.MI': -0.085,
#   'CAP.PA': -0.048,
#   '6S=F': 0.677,
#   'AMS.MC': -0.144,
#   'SAMPO.HE': 0.105,
#   'LR.PA': -0.101,
#   'VNA.DE': 0.141,
#   'CABK.MC': -0.02,
#   'PUB.PA': 0.162,
#   'COLO-B.CO': -0.004,
#   'SHB-A.ST': 0.106,
#   'SCMN.SW': 0.17,
#   'KBC.BR': 0.058,
#   'HNR1.DE': 0.178,
#   'BNR.DE': -0.117,
#   'TRN.MI': 0.009,
#   'BVI.PA': 0.002,
#   'SIG': 0.0,
#   'VIV.PA': -0.027,
#   'PNDORA.CO': -0.038,
#   'WFDRX': 0.127,
#   'MB.MI': 0.064,
#   'ATL.MI': -0.068,
#   'BOL.PA': -0.044,
#   'GFC.PA': 0.107,
#   'SECU-B.ST': -0.055,
#   'IDVA.SG': -0.005,
#   'FR.PA': -0.015,
#   'COV.PA': -0.014,
#   'MF.PA': 0.063},
#  'Q3-2014': {'ASML': -0.015,
#   'MC.PA': 0.073,
#   'NVS': 0.039,
#   'SAP': -0.114,
#   'CFR.SW': -0.044,
#   'RMS.PA': -0.088,
#   'KER.PA': -0.078,
#   'RI.PA': 0.016,
#   'ISP.MI': 0.006,
#   'IDEXF': -0.112,
#   'AMS.MC': 0.024,
#   'SAMPO.HE': 0.045,
#   'ADDYY': 0.056,
#   'LR.PA': 0.022,
#   'G.MI': 0.019,
#   'VNA.DE': 0.037,
#   'KNEBV.HE': 0.032,
#   'CABK.MC': 0.024,
#   'COLO-B.CO': 0.071,
#   'SCMN.SW': 0.048,
#   'HNR1.DE': 0.105,
#   'QGEN': -0.003,
#   'BNR.DE': -0.041,
#   'TRN.MI': -0.043,
#   'EBS.VI': -0.086,
#   'RDFN': 0.427,
#   'TELIA.ST': -0.027,
#   'SIG': 0.02,
#   'PNDORA.CO': -0.022,
#   'JMT.LS': 0.053,
#   'MB.MI': 0.025,
#   'ATL.MI': -0.007,
#   'LI.PA': -0.012,
#   'BOL.PA': -0.033,
#   'GFC.PA': -0.02,
#   'SECU-B.ST': 0.031,
#   'IDVA.SG': 0.095,
#   'FR.PA': -0.032,
#   'LBGUF': 0.423,
#   'COV.PA': 0.086},
#  'Q4-2014': {'ASML': 0.015,
#   'NVS': -0.042,
#   'SAP': -0.171,
#   'ABB': -0.041,
#   'KER.PA': -0.004,
#   'RI.PA': 0.151,
#   'CAP.PA': -0.023,
#   'IDEXF': -0.002,
#   '6S=F': 0.312,
#   'VNA.DE': 0.039,
#   'KNEBV.HE': 0.068,
#   'CABK.MC': 0.008,
#   'SCMN.SW': 0.046,
#   'KBC.BR': 0.027,
#   'QGEN': 0.013,
#   'RDFN': 1.0,
#   'SIG': -0.018,
#   'VIV.PA': 0.023,
#   'PNDORA.CO': 0.011,
#   'WFDRX': 0.022,
#   'BOL.PA': 0.021,
#   'DIE.BR': 0.044,
#   'LBGUF': -0.5},
#  'Q1-2015': {'ASML': 0.06,
#   'MC.PA': 0.017,
#   'NVS': -0.348,
#   'RMS.PA': -0.049,
#   'ISP.MI': 0.004,
#   'IDEXF': 0.019,
#   '6S=F': 0.365,
#   'AMS.MC': -0.07,
#   'SAMPO.HE': 0.15,
#   'G.MI': 0.053,
#   'VNA.DE': -0.021,
#   'KNEBV.HE': -0.038,
#   'PUB.PA': 0.026,
#   'COLO-B.CO': -0.029,
#   'SHB-A.ST': -0.13,
#   'SCMN.SW': 0.103,
#   'KBC.BR': -0.043,
#   'HNR1.DE': -0.045,
#   'QGEN': -0.099,
#   'BNR.DE': 0.065,
#   'EBS.VI': 0.009,
#   'RDFN': 0.984,
#   'TELIA.ST': 0.095,
#   'ZAL.DE': -0.008,
#   'SIG': 0.025,
#   'VIV.PA': 0.206,
#   'PNDORA.CO': 0.066,
#   'SECU-B.ST': 0.002,
#   'IDVA.SG': 0.093,
#   'FR.PA': -0.046,
#   'LBGUF': -0.514,
#   'COV.PA': 0.1},
#  'Q2-2015': {'ASML': -0.342,
#   'MC.PA': 0.058,
#   'NVS': -0.272,
#   'SAP': -0.273,
#   'CFR.SW': 0.09,
#   'ABB': 0.216,
#   'RMS.PA': -0.093,
#   'KER.PA': 0.478,
#   'RI.PA': -0.109,
#   'ISP.MI': 0.184,
#   'CAP.PA': 0.136,
#   'IDEXF': 0.084,
#   '6S=F': 0.045,
#   'AMS.MC': -0.038,
#   'SAMPO.HE': -0.922,
#   'ADDYY': -0.031,
#   'LR.PA': -0.02,
#   'G.MI': 0.002,
#   'VNA.DE': 0.015,
#   'KNEBV.HE': 0.015,
#   'PUB.PA': 0.137,
#   'COLO-B.CO': 0.504,
#   'SHB-A.ST': 0.131,
#   'SCMN.SW': -0.049,
#   'KBC.BR': -0.09,
#   'HNR1.DE': -0.067,
#   'QGEN': -0.098,
#   'BNR.DE': 0.102,
#   'TRN.MI': 0.233,
#   'EBS.VI': -0.086,
#   'AENA.MC': -0.09,
#   'GBLC.CN': 0.013,
#   'RDFN': 1.0,
#   'BVI.PA': 0.03,
#   'TELIA.ST': -0.407,
#   'RAND.AS': -0.384,
#   'SIG': -0.272,
#   'VIV.PA': 0.464,
#   'PNDORA.CO': -0.036,
#   'JMT.LS': 0.055,
#   'WFDRX': 0.509,
#   'MB.MI': 0.049,
#   'ATL.MI': 0.02,
#   'LI.PA': 0.226,
#   'BOL.PA': 0.108,
#   'DIE.BR': 0.098,
#   'GFC.PA': 0.482,
#   'SECU-B.ST': -0.039,
#   'IDVA.SG': -0.124,
#   'FR.PA': -0.212,
#   'LBGUF': -0.177,
#   'COV.PA': -0.273,
#   'MF.PA': 0.015},
#  'Q3-2015': {'ABB': -0.141,
#   'RMS.PA': 0.065,
#   'ISP.MI': -0.181,
#   'CAP.PA': 0.113,
#   'IDEXF': 0.116,
#   '6S=F': 0.402,
#   'LR.PA': -0.05,
#   'CABK.MC': 0.182,
#   'KBC.BR': -0.048,
#   'TRN.MI': 0.218,
#   'EBS.VI': -0.03,
#   'AENA.MC': -0.051,
#   'GBLC.CN': -0.006,
#   'BVI.PA': 0.222,
#   'ZAL.DE': -0.042,
#   'VIV.PA': 0.055,
#   'PNDORA.CO': 0.048,
#   'JMT.LS': -0.065,
#   'MB.MI': -0.032,
#   'DIE.BR': 0.156,
#   'FR.PA': 0.069},
#  'Q4-2015': {'SAMPO.HE': 0.057,
#   'VNA.DE': -0.053,
#   'COLO-B.CO': 0.101,
#   'SHB-A.ST': -0.022,
#   'HNR1.DE': 0.047,
#   'QGEN': 0.272,
#   'TRN.MI': 0.441,
#   'EBS.VI': -0.055,
#   'AENA.MC': 0.383,
#   'GBLC.CN': -0.027,
#   'SIG': 0.008,
#   'PNDORA.CO': -0.058,
#   'JMT.LS': -0.077,
#   'MB.MI': -0.026,
#   'ATL.MI': -0.24,
#   'DIE.BR': 0.251},
#  'Q1-2016': {'SAP': -0.071,
#   'CFR.SW': 0.027,
#   'KER.PA': -0.067,
#   'RI.PA': 0.047,
#   'CAP.PA': -0.074,
#   'IDEXF': -0.033,
#   '6S=F': 0.209,
#   'AMS.MC': -0.032,
#   'SAMPO.HE': -0.046,
#   'ADDYY': -0.107,
#   'LR.PA': 0.069,
#   'G.MI': -0.156,
#   'KNEBV.HE': 0.089,
#   'COLO-B.CO': 0.071,
#   'HNR1.DE': 0.006,
#   'QGEN': 0.004,
#   'TRN.MI': 0.108,
#   'EBS.VI': 0.084,
#   'AENA.MC': 0.181,
#   'RDFN': 0.234,
#   'RAND.AS': -0.091,
#   'ZAL.DE': 0.067,
#   'PNDORA.CO': 0.007,
#   'ATL.MI': 0.036,
#   'LI.PA': 0.072,
#   'GFC.PA': 0.065,
#   'SECU-B.ST': -0.038,
#   'FR.PA': 0.005,
#   'LBGUF': 0.227,
#   'COV.PA': 0.105},
#  'Q2-2016': {'ASML': -0.036,
#   'MC.PA': -0.062,
#   'ABB': 0.193,
#   'RMS.PA': 0.338,
#   'KER.PA': -0.354,
#   'RI.PA': 0.302,
#   'AMS.MC': 0.008,
#   'ADDYY': 0.22,
#   'VNA.DE': -0.361,
#   'KNEBV.HE': -0.096,
#   'PUB.PA': 0.183,
#   'SHB-A.ST': -0.152,
#   'SCMN.SW': 0.198,
#   'TRN.MI': 0.196,
#   'AENA.MC': -0.038,
#   'BVI.PA': 0.44,
#   'TELIA.ST': 0.075,
#   'VIV.PA': -0.01,
#   'PNDORA.CO': -0.093,
#   'JMT.LS': -0.157,
#   'ATL.MI': 0.178,
#   'LI.PA': 0.065,
#   'DIE.BR': 0.064,
#   'GFC.PA': 0.326,
#   'SECU-B.ST': -0.219,
#   'FR.PA': -0.016,
#   'COV.PA': -0.194},
#  'Q3-2016': {'NVS': -0.06,
#   'ABB': 0.035,
#   'CAP.PA': 0.017,
#   '6S=F': 0.654,
#   'AMS.MC': 0.193,
#   'ADDYY': -0.127,
#   'AENA.MC': 0.087,
#   'PNDORA.CO': 0.032,
#   'WFDRX': 0.06,
#   'DIE.BR': 0.036,
#   'GFC.PA': 0.047,
#   'MF.PA': 0.025},
#  'Q4-2016': {'ASML': -0.013,
#   'MC.PA': 0.04,
#   'NVS': -0.081,
#   'SAP': -0.206,
#   'CFR.SW': 0.032,
#   'ABB': 0.007,
#   'RMS.PA': 0.112,
#   'KER.PA': -0.05,
#   'RI.PA': 0.173,
#   'ISP.MI': 0.08,
#   'CAP.PA': 0.067,
#   'IDEXF': -0.02,
#   'AMS.MC': 0.066,
#   'SAMPO.HE': -0.095,
#   'ADDYY': 0.051,
#   'LR.PA': 0.111,
#   'G.MI': 0.08,
#   'VNA.DE': 0.102,
#   'KNEBV.HE': -0.089,
#   'CABK.MC': -0.098,
#   'PUB.PA': -0.156,
#   'COLO-B.CO': 0.229,
#   'SHB-A.ST': -0.054,
#   'SCMN.SW': 0.106,
#   'KBC.BR': -0.084,
#   'HNR1.DE': -0.02,
#   'QGEN': -0.1,
#   'BNR.DE': 0.17,
#   'EBS.VI': 0.022,
#   'AENA.MC': 0.222,
#   'GBLC.CN': 0.006,
#   'RDFN': 0.523,
#   'BVI.PA': -0.051,
#   'TELIA.ST': -0.059,
#   'ZAL.DE': -0.007,
#   'VIV.PA': -0.146,
#   'JMT.LS': -0.018,
#   'WFDRX': -0.148,
#   'MB.MI': 0.02,
#   'ATL.MI': 0.024,
#   'LI.PA': 0.186,
#   'BOL.PA': -0.058,
#   'DIE.BR': 0.038,
#   'GFC.PA': 0.023,
#   'SECU-B.ST': -0.066,
#   'IDVA.SG': 0.001,
#   'FR.PA': 0.059,
#   'LBGUF': 0.494,
#   'COV.PA': -0.428,
#   'MF.PA': 0.004},
#  'Q1-2017': {'ASML': -0.044,
#   'MC.PA': -0.131,
#   'SAP': -0.047,
#   'CFR.SW': -0.073,
#   'ABB': -0.037,
#   'RMS.PA': 0.126,
#   'KER.PA': -0.001,
#   'ISP.MI': 0.077,
#   'IDEXF': -0.006,
#   '6S=F': 0.158,
#   'SAMPO.HE': 0.171,
#   'LR.PA': 0.095,
#   'G.MI': -0.036,
#   'CABK.MC': -0.024,
#   'SHB-A.ST': -0.187,
#   'KBC.BR': 0.026,
#   'HNR1.DE': 0.005,
#   'QGEN': 0.069,
#   'BNR.DE': -0.026,
#   'EBS.VI': -0.012,
#   'AENA.MC': -0.033,
#   'GBLC.CN': 0.001,
#   'RDFN': 1.0,
#   'RAND.AS': -0.028,
#   'SIG': 0.01,
#   'VIV.PA': -0.069,
#   'PNDORA.CO': 0.104,
#   'JMT.LS': 0.12,
#   'WFDRX': -0.218,
#   'MB.MI': -0.021,
#   'BOL.PA': 0.022,
#   'IDVA.SG': 0.041,
#   'FR.PA': 0.103,
#   'LBGUF': -0.311,
#   'MF.PA': 0.178},
#  'Q2-2017': {'ASML': -0.009,
#   'MC.PA': -0.006,
#   'NVS': 0.067,
#   'SAP': -0.262,
#   'CFR.SW': 0.01,
#   'ABB': 0.032,
#   'RMS.PA': 0.142,
#   'KER.PA': 0.079,
#   'RI.PA': 0.029,
#   'ISP.MI': -0.063,
#   'CAP.PA': -0.025,
#   '6S=F': 0.605,
#   'AMS.MC': 0.13,
#   'SAMPO.HE': 0.063,
#   'ADDYY': -0.036,
#   'LR.PA': 0.082,
#   'G.MI': -0.006,
#   'VNA.DE': -0.063,
#   'CABK.MC': -0.122,
#   'COLO-B.CO': 0.044,
#   'SCMN.SW': 0.162,
#   'KBC.BR': 0.139,
#   'HNR1.DE': 0.075,
#   'QGEN': -0.051,
#   'BNR.DE': -0.06,
#   'TRN.MI': -0.029,
#   'EBS.VI': -0.007,
#   'AENA.MC': 0.026,
#   'TELIA.ST': -0.161,
#   'RAND.AS': -0.018,
#   'ZAL.DE': 0.002,
#   'JMT.LS': 0.099,
#   'WFDRX': -0.181,
#   'MB.MI': 0.033,
#   'ATL.MI': 0.176,
#   'BOL.PA': -0.014,
#   'DIE.BR': 0.008,
#   'SECU-B.ST': 0.014,
#   'IDVA.SG': 0.065,
#   'FR.PA': 0.033},
#  'Q3-2017': {'MC.PA': 0.032,
#   'NVS': 0.13,
#   'SAP': 0.007,
#   'CFR.SW': 0.038,
#   'ABB': -0.099,
#   'RMS.PA': 0.239,
#   'KER.PA': 0.05,
#   'RI.PA': 0.107,
#   'ISP.MI': -0.006,
#   'CAP.PA': 0.049,
#   'IDEXF': 0.126,
#   'AMS.MC': -0.018,
#   'SAMPO.HE': -0.026,
#   'LR.PA': 0.079,
#   'VNA.DE': 0.177,
#   'KNEBV.HE': -0.004,
#   'CABK.MC': -0.009,
#   'PUB.PA': 0.031,
#   'COLO-B.CO': 0.021,
#   'SCMN.SW': 0.036,
#   'KBC.BR': 0.171,
#   'QGEN': -0.043,
#   'TRN.MI': -0.064,
#   'EBS.VI': 0.09,
#   'AENA.MC': -0.064,
#   'BVI.PA': 0.032,
#   'TELIA.ST': 0.273,
#   'ZAL.DE': 0.098,
#   'VIV.PA': -0.115,
#   'JMT.LS': 0.081,
#   'MB.MI': 0.045,
#   'ATL.MI': 0.006,
#   'LI.PA': 0.038,
#   'BOL.PA': -0.108,
#   'DIE.BR': 0.109,
#   'GFC.PA': 0.007,
#   'SECU-B.ST': 0.04,
#   'IDVA.SG': 0.009,
#   'FR.PA': -0.15,
#   'COV.PA': -0.174,
#   'MF.PA': -0.243},
#  'Q4-2017': {'ASML': 0.068,
#   'CFR.SW': 0.254,
#   'KER.PA': -0.18,
#   'ISP.MI': 0.22,
#   'CAP.PA': -0.046,
#   'ADDYY': -0.056,
#   'G.MI': 0.148,
#   'VNA.DE': 0.32,
#   'KNEBV.HE': 0.113,
#   'EBS.VI': 0.011,
#   'RDFN': 0.002,
#   'SIG': 0.027,
#   'PNDORA.CO': -0.001,
#   'ATL.MI': 0.119},
#  'Q1-2018': {'ASML': 0.058,
#   'MC.PA': -0.043,
#   'SAP': -0.126,
#   'ABB': -0.07,
#   'RMS.PA': 0.141,
#   'KER.PA': 0.008,
#   'RI.PA': 0.045,
#   'CAP.PA': 0.087,
#   'IDEXF': 0.003,
#   'AMS.MC': -0.001,
#   'SAMPO.HE': 0.202,
#   'LR.PA': -0.063,
#   'G.MI': -0.004,
#   'VNA.DE': 0.005,
#   'PUB.PA': 0.011,
#   'SCMN.SW': -0.046,
#   'KBC.BR': 0.065,
#   'HNR1.DE': -0.019,
#   'BNR.DE': -0.043,
#   'TRN.MI': 0.085,
#   'EBS.VI': 0.004,
#   'AENA.MC': 0.036,
#   'RDFN': 0.017,
#   'BVI.PA': -0.125,
#   'RAND.AS': 0.03,
#   'ZAL.DE': -0.041,
#   'VIV.PA': 0.0,
#   'WFDRX': -0.256,
#   'MB.MI': -0.035,
#   'ATL.MI': -0.037,
#   'LI.PA': 0.087,
#   'BOL.PA': 0.092,
#   'DIE.BR': -0.033,
#   'GFC.PA': -0.001,
#   'SECU-B.ST': -0.118,
#   'IDVA.SG': 0.105,
#   'FR.PA': -0.006,
#   'LBGUF': 0.667,
#   'COV.PA': 0.149,
#   'MF.PA': 0.171},
#  'Q2-2018': {'ASML': 0.006,
#   'RMS.PA': 0.263,
#   'KER.PA': -0.193,
#   'RI.PA': 0.025,
#   'ISP.MI': 0.019,
#   'CAP.PA': 0.03,
#   '6S=F': 0.475,
#   'AMS.MC': -0.113,
#   'SAMPO.HE': 0.058,
#   'LR.PA': 0.133,
#   'G.MI': 0.06,
#   'PUB.PA': 0.001,
#   'COLO-B.CO': 0.033,
#   'SHB-A.ST': -0.094,
#   'KBC.BR': 0.046,
#   'HNR1.DE': 0.09,
#   'QGEN': 0.033,
#   'EBS.VI': 0.032,
#   'AENA.MC': 0.119,
#   'TELIA.ST': -0.016,
#   'RAND.AS': 0.057,
#   'ZAL.DE': 0.044,
#   'MB.MI': 0.015,
#   'BOL.PA': 0.012,
#   'MF.PA': -0.135},
#  'Q3-2018': {'ASML': -0.014,
#   'MC.PA': 0.02,
#   'SAP': -0.01,
#   'CFR.SW': 0.019,
#   'RMS.PA': 0.005,
#   'KER.PA': -0.034,
#   'RI.PA': 0.078,
#   'CAP.PA': 0.002,
#   'IDEXF': -0.019,
#   '6S=F': 0.169,
#   'AMS.MC': 0.001,
#   'ADDYY': -0.018,
#   'VNA.DE': -0.011,
#   'KNEBV.HE': 0.096,
#   'COLO-B.CO': 0.01,
#   'QGEN': -0.069,
#   'RDFN': -0.034,
#   'TELIA.ST': -0.004,
#   'SIG': -0.007,
#   'VIV.PA': 0.038,
#   'WFDRX': 0.061,
#   'GFC.PA': 0.136,
#   'LBGUF': 0.585},
#  'Q4-2018': {'NVS': -0.157,
#   'ABB': -0.01,
#   '6S=F': 0.252,
#   'AMS.MC': -0.036,
#   'SAMPO.HE': 0.136,
#   'ADDYY': -0.046,
#   'G.MI': -0.018,
#   'VNA.DE': 0.044,
#   'KNEBV.HE': 0.001,
#   'CABK.MC': 0.041,
#   'COLO-B.CO': 0.016,
#   'SHB-A.ST': 0.066,
#   'HNR1.DE': 0.058,
#   'QGEN': -0.03,
#   'BNR.DE': 0.021,
#   'TRN.MI': 0.011,
#   'BVI.PA': 0.073,
#   'SIG': 0.005,
#   'VIV.PA': 0.052,
#   'WFDRX': 0.089,
#   'MB.MI': -0.037,
#   'DIE.BR': 0.03,
#   'SECU-B.ST': 0.028,
#   'LBGUF': 0.32,
#   'COV.PA': 0.128,
#   'MF.PA': -0.034},
#  'Q1-2019': {'NVS': -0.112,
#   'RI.PA': 0.044,
#   'IDEXF': -0.004,
#   'SCMN.SW': -0.021,
#   'TRN.MI': 0.071,
#   'TELIA.ST': 0.075,
#   'LBGUF': 0.948},
#  'Q2-2019': {'ASML': -0.003,
#   'MC.PA': 0.027,
#   'NVS': -0.097,
#   'SAP': 0.058,
#   'CFR.SW': -0.066,
#   'RMS.PA': 0.086,
#   'KER.PA': -0.11,
#   'RI.PA': 0.023,
#   'ISP.MI': -0.042,
#   'CAP.PA': -0.032,
#   'AMS.MC': 0.025,
#   'SAMPO.HE': 0.102,
#   'ADDYY': 0.084,
#   'LR.PA': -0.109,
#   'G.MI': 0.099,
#   'VNA.DE': -0.012,
#   'KNEBV.HE': 0.016,
#   'PUB.PA': 0.053,
#   'COLO-B.CO': 0.094,
#   'SHB-A.ST': -0.013,
#   'SCMN.SW': -0.107,
#   'KBC.BR': -0.012,
#   'HNR1.DE': 0.086,
#   'QGEN': 0.034,
#   'BNR.DE': -0.078,
#   'TRN.MI': 0.077,
#   'AENA.MC': 0.044,
#   'GBLC.CN': -0.004,
#   'RDFN': -0.008,
#   'BVI.PA': -0.083,
#   'RAND.AS': 0.089,
#   'ZAL.DE': -0.018,
#   'VIV.PA': 0.05,
#   'JMT.LS': -0.035,
#   'MB.MI': -0.01,
#   'ATL.MI': -0.012,
#   'LI.PA': -0.094,
#   'BOL.PA': 0.007,
#   'DIE.BR': -0.018,
#   'GFC.PA': 0.068,
#   'IDVA.SG': 0.092,
#   'FR.PA': 0.021,
#   'LBGUF': 0.627,
#   'COV.PA': 0.007,
#   'MF.PA': 0.094},
#  'Q3-2019': {'ASML': -0.027,
#   'MC.PA': 0.035,
#   'NVS': -0.01,
#   'SAP': -0.032,
#   'CFR.SW': 0.037,
#   'ABB': -0.105,
#   'RMS.PA': 0.038,
#   'RI.PA': 0.073,
#   '6S=F': 0.608,
#   'AMS.MC': -0.022,
#   'ADDYY': -0.0,
#   'LR.PA': 0.054,
#   'G.MI': 0.134,
#   'VNA.DE': 0.09,
#   'KNEBV.HE': 0.03,
#   'COLO-B.CO': 0.01,
#   'SCMN.SW': -0.02,
#   'HNR1.DE': -0.003,
#   'TRN.MI': -0.051,
#   'EBS.VI': 0.002,
#   'AENA.MC': -0.034,
#   'RAND.AS': 0.011,
#   'ZAL.DE': -0.015,
#   'JMT.LS': 0.021,
#   'WFDRX': 0.068,
#   'ATL.MI': -0.04,
#   'BOL.PA': 0.008,
#   'DIE.BR': 0.034,
#   'GFC.PA': -0.004,
#   'SECU-B.ST': 0.085,
#   'IDVA.SG': 0.024,
#   'COV.PA': 0.017,
#   'MF.PA': -0.019},
#  'Q4-2019': {'ASML': -0.0,
#   'MC.PA': -0.007,
#   'NVS': -0.128,
#   'CFR.SW': 0.159,
#   'ABB': 0.045,
#   'RMS.PA': -0.132,
#   'RI.PA': 0.058,
#   'ISP.MI': -0.062,
#   'CAP.PA': 0.032,
#   'IDEXF': 0.005,
#   '6S=F': 0.122,
#   'ADDYY': -0.056,
#   'LR.PA': 0.038,
#   'G.MI': 0.202,
#   'KNEBV.HE': 0.032,
#   'COLO-B.CO': 0.086,
#   'SCMN.SW': 0.125,
#   'HNR1.DE': -0.145,
#   'BNR.DE': -0.03,
#   'TRN.MI': -0.088,
#   'BVI.PA': -0.067,
#   'TELIA.ST': -0.002,
#   'ZAL.DE': 0.036,
#   'VIV.PA': 0.136,
#   'PNDORA.CO': -0.007,
#   'JMT.LS': -0.001,
#   'WFDRX': -0.094,
#   'MB.MI': 0.058,
#   'ATL.MI': 0.02,
#   'DIE.BR': -0.017,
#   'GFC.PA': 0.004,
#   'IDVA.SG': -0.064,
#   'FR.PA': -0.004,
#   'LBGUF': 0.766,
#   'COV.PA': -0.024,
#   'MF.PA': 0.003},
#  'Q1-2020': {'ASML': -0.08,
#   'MC.PA': -0.115,
#   'NVS': -0.047,
#   'SAP': -0.11,
#   'ABB': 0.043,
#   'RMS.PA': 0.058,
#   'KER.PA': -0.101,
#   'ISP.MI': 0.025,
#   'AMS.MC': 0.074,
#   'SAMPO.HE': 0.212,
#   'LR.PA': -0.043,
#   'G.MI': 0.12,
#   'VNA.DE': -0.063,
#   'KNEBV.HE': 0.164,
#   'CABK.MC': 0.03,
#   'SHB-A.ST': 0.086,
#   'SCMN.SW': 0.152,
#   'KBC.BR': -0.08,
#   'HNR1.DE': 0.129,
#   'QGEN': -0.003,
#   'BNR.DE': 0.037,
#   'EBS.VI': 0.026,
#   'RDFN': 0.019,
#   'BVI.PA': 0.096,
#   'RAND.AS': -0.229,
#   'SIG': -0.025,
#   'WFDRX': 0.159,
#   'MB.MI': 0.151,
#   'LI.PA': 0.108,
#   'DIE.BR': -0.061,
#   'GFC.PA': 0.379,
#   'SECU-B.ST': -0.029,
#   'IDVA.SG': 0.011,
#   'FR.PA': -0.01,
#   'COV.PA': -0.083},
#  'Q2-2020': {'ASML': 0.027,
#   '6S=F': 0.836,
#   'VNA.DE': -0.013,
#   'COLO-B.CO': -0.014,
#   'SHB-A.ST': 0.006,
#   'SCMN.SW': 0.079,
#   'TRN.MI': -0.031,
#   'GBLC.CN': -0.004,
#   'RDFN': -0.011,
#   'SIG': 0.002,
#   'PNDORA.CO': 0.011,
#   'JMT.LS': 0.073,
#   'GFC.PA': 0.039},
#  'Q3-2020': {'ASML': -0.192,
#   'MC.PA': 0.106,
#   'SAP': -0.117,
#   'CFR.SW': -0.085,
#   'ABB': 0.074,
#   'RMS.PA': 0.136,
#   'KER.PA': 0.012,
#   'CAP.PA': -0.078,
#   'ADDYY': 0.131,
#   'LR.PA': 0.043,
#   'VNA.DE': 0.203,
#   'KNEBV.HE': 0.149,
#   'COLO-B.CO': -0.004,
#   'HNR1.DE': 0.008,
#   'QGEN': 0.559,
#   'BNR.DE': -0.261,
#   'TRN.MI': -0.193,
#   'AENA.MC': -0.02,
#   'GBLC.CN': -0.012,
#   'RDFN': -0.094,
#   'RAND.AS': 0.017,
#   'ZAL.DE': -0.028,
#   'PNDORA.CO': -0.092,
#   'WFDRX': 0.195,
#   'BOL.PA': 0.093,
#   'DIE.BR': 0.042,
#   'SECU-B.ST': 0.045,
#   'IDVA.SG': 0.202,
#   'FR.PA': -0.054,
#   'LBGUF': 0.214},
#  'Q4-2020': {'SAP': -0.162,
#   'ABB': 0.011,
#   'KER.PA': 0.047,
#   'ISP.MI': -0.001,
#   'CAP.PA': -0.023,
#   '6S=F': 0.621,
#   'SAMPO.HE': 0.106,
#   'ADDYY': -0.051,
#   'LR.PA': -0.009,
#   'VNA.DE': 0.044,
#   'KNEBV.HE': 0.209,
#   'SCMN.SW': 0.058,
#   'QGEN': 0.059,
#   'BNR.DE': -0.044,
#   'RDFN': -0.0,
#   'TELIA.ST': 0.077,
#   'RAND.AS': 0.048,
#   'ZAL.DE': -0.033,
#   'SIG': -0.027,
#   'VIV.PA': -0.004,
#   'PNDORA.CO': 0.058,
#   'WFDRX': 0.109,
#   'MB.MI': 0.038,
#   'BOL.PA': -0.09,
#   'IDVA.SG': -0.008,
#   'FR.PA': -0.033},
#  'Q1-2021': {'ASML': 0.006,
#   'MC.PA': -0.021,
#   'NVS': 0.049,
#   'CFR.SW': 0.027,
#   'ABB': -0.103,
#   'RMS.PA': -0.01,
#   'KER.PA': 0.04,
#   'RI.PA': 0.055,
#   'ISP.MI': -0.159,
#   'IDEXF': 0.054,
#   '6S=F': 0.777,
#   'AMS.MC': -0.05,
#   'SAMPO.HE': -0.082,
#   'ADDYY': -0.102,
#   'G.MI': -0.014,
#   'CABK.MC': -0.013,
#   'PUB.PA': -0.073,
#   'SHB-A.ST': -0.016,
#   'KBC.BR': 0.062,
#   'BNR.DE': -0.031,
#   'TRN.MI': 0.027,
#   'EBS.VI': -0.024,
#   'AENA.MC': 0.022,
#   'GBLC.CN': 0.005,
#   'RDFN': -0.047,
#   'BVI.PA': -0.108,
#   'TELIA.ST': -0.098,
#   'RAND.AS': -0.003,
#   'ZAL.DE': -0.012,
#   'SIG': 0.015,
#   'VIV.PA': 0.159,
#   'PNDORA.CO': -0.041,
#   'JMT.LS': 0.039,
#   'WFDRX': 0.09,
#   'MB.MI': 0.067,
#   'ATL.MI': -0.011,
#   'LI.PA': -0.031,
#   'BOL.PA': 0.052,
#   'DIE.BR': 0.07,
#   'GFC.PA': 0.044,
#   'SECU-B.ST': 0.052,
#   'IDVA.SG': 0.08,
#   'FR.PA': -0.014,
#   'COV.PA': 0.037,
#   'MF.PA': 0.233},
#  'Q2-2021': {'ASML': -0.082,
#   'MC.PA': -0.27,
#   'SAP': 0.111,
#   'CFR.SW': 0.032,
#   'ABB': 0.015,
#   'RMS.PA': 0.307,
#   'ISP.MI': -0.187,
#   'CAP.PA': -0.023,
#   'IDEXF': 0.066,
#   'SAMPO.HE': -0.013,
#   'ADDYY': -0.004,
#   'LR.PA': -0.064,
#   'G.MI': -0.16,
#   'CABK.MC': 0.103,
#   'PUB.PA': 0.01,
#   'SHB-A.ST': 0.196,
#   'HNR1.DE': -0.123,
#   'BNR.DE': 0.098,
#   'EBS.VI': -0.006,
#   'AENA.MC': -0.057,
#   'GBLC.CN': -0.007,
#   'RDFN': 0.053,
#   'BVI.PA': 0.265,
#   'TELIA.ST': 0.288,
#   'RAND.AS': 0.119,
#   'ZAL.DE': -0.013,
#   'SIG': -0.048,
#   'VIV.PA': 0.159,
#   'MB.MI': 0.073,
#   'ATL.MI': 0.131,
#   'LI.PA': 0.041,
#   'BOL.PA': -0.228,
#   'DIE.BR': -0.039,
#   'IDVA.SG': 0.109,
#   'LBGUF': 0.217,
#   'MF.PA': -0.069},
#  'Q3-2021': {'ASML': -0.074,
#   'MC.PA': -0.116,
#   'NVS': 0.031,
#   'SAP': 0.091,
#   'CFR.SW': 0.038,
#   'ABB': -0.153,
#   'RMS.PA': 0.114,
#   'KER.PA': -0.005,
#   'RI.PA': -0.135,
#   'ISP.MI': 0.061,
#   'CAP.PA': 0.009,
#   'IDEXF': 0.022,
#   '6S=F': 0.374,
#   'AMS.MC': -0.024,
#   'SAMPO.HE': 0.109,
#   'ADDYY': -0.013,
#   'LR.PA': -0.046,
#   'G.MI': -0.042,
#   'KNEBV.HE': 0.103,
#   'CABK.MC': 0.117,
#   'PUB.PA': 0.084,
#   'COLO-B.CO': 0.041,
#   'SCMN.SW': 0.089,
#   'KBC.BR': -0.023,
#   'BNR.DE': -0.017,
#   'TRN.MI': -0.088,
#   'EBS.VI': 0.07,
#   'BVI.PA': 0.364,
#   'TELIA.ST': 0.028,
#   'RAND.AS': 0.017,
#   'ZAL.DE': -0.079,
#   'SIG': 0.006,
#   'VIV.PA': -0.109,
#   'PNDORA.CO': 0.042,
#   'JMT.LS': 0.055,
#   'WFDRX': 0.133,
#   'MB.MI': -0.014,
#   'LI.PA': -0.061,
#   'BOL.PA': 0.139,
#   'DIE.BR': -0.017,
#   'GFC.PA': 0.186,
#   'IDVA.SG': 0.019,
#   'COV.PA': -0.075,
#   'MF.PA': -0.254},
#  'Q4-2021': {'ASML': -0.011,
#   'NVS': -0.122,
#   'SAP': -0.028,
#   'ABB': -0.097,
#   'RMS.PA': -0.02,
#   'RI.PA': 0.016,
#   'CAP.PA': 0.04,
#   '6S=F': 0.268,
#   'SAMPO.HE': -0.1,
#   'ADDYY': -0.018,
#   'LR.PA': 0.187,
#   'G.MI': -0.026,
#   'VNA.DE': -0.015,
#   'KNEBV.HE': -0.022,
#   'COLO-B.CO': 0.048,
#   'SHB-A.ST': 0.054,
#   'SCMN.SW': 0.053,
#   'KBC.BR': 0.036,
#   'HNR1.DE': 0.006,
#   'QGEN': 0.047,
#   'BNR.DE': 0.007,
#   'TRN.MI': 0.005,
#   'EBS.VI': -0.022,
#   'BVI.PA': 0.061,
#   'TELIA.ST': 0.097,
#   'SIG': 0.004,
#   'VIV.PA': 0.019,
#   'JMT.LS': 0.023,
#   'WFDRX': -0.036,
#   'BOL.PA': 0.034,
#   'DIE.BR': -0.004,
#   'SECU-B.ST': -0.075,
#   'LBGUF': 0.528,
#   'MF.PA': 0.061},
#  'Q1-2022': {'MC.PA': -0.049,
#   'CFR.SW': -0.031,
#   'RMS.PA': 0.007,
#   'KER.PA': 0.029,
#   'RI.PA': -0.014,
#   'CAP.PA': 0.018,
#   '6S=F': 0.025,
#   'AMS.MC': 0.008,
#   'LR.PA': 0.006,
#   'G.MI': -0.005,
#   'PUB.PA': 0.023,
#   'KBC.BR': 0.031,
#   'HNR1.DE': 0.1,
#   'QGEN': -0.001,
#   'EBS.VI': -0.054,
#   'BVI.PA': 0.047,
#   'SIG': -0.01,
#   'PNDORA.CO': 0.032,
#   'JMT.LS': 0.048,
#   'ATL.MI': 0.015,
#   'DIE.BR': -0.051,
#   'FR.PA': -0.032,
#   'LBGUF': 0.86},
#  'Q2-2022': {'NVS': -0.067,
#   '6S=F': 0.005,
#   'AMS.MC': 0.03,
#   'CABK.MC': 0.054,
#   'SCMN.SW': 0.015,
#   'TRN.MI': 0.054,
#   'AENA.MC': -0.038,
#   'LI.PA': -0.014,
#   'LBGUF': 0.961},
#  'Q3-2022': {'NVS': -0.123,
#   'IDEXF': -0.063,
#   'SAMPO.HE': 0.025,
#   'CABK.MC': 0.017,
#   'SHB-A.ST': 0.004,
#   'SCMN.SW': 0.075,
#   'BNR.DE': -0.049,
#   'TRN.MI': 0.023,
#   'AENA.MC': 0.17,
#   'BVI.PA': 0.046,
#   'TELIA.ST': 0.024,
#   'VIV.PA': 0.098,
#   'MB.MI': -0.08,
#   'ATL.MI': -0.032,
#   'BOL.PA': 0.067,
#   'DIE.BR': -0.033,
#   'GFC.PA': 0.016,
#   'IDVA.SG': 0.074,
#   'FR.PA': 0.024,
#   'LBGUF': 0.847,
#   'MF.PA': -0.131},
#  'Q4-2022': {'MC.PA': 0.042,
#   'RMS.PA': -0.006,
#   'RI.PA': 0.016,
#   '6S=F': 0.06,
#   'SAMPO.HE': -0.067,
#   'COLO-B.CO': 0.002,
#   'HNR1.DE': -0.033,
#   'QGEN': -0.035,
#   'JMT.LS': 0.002,
#   'WFDRX': 0.011,
#   'ATL.MI': 0.72,
#   'LBGUF': 0.288}}

# %% [markdown]
# Now we are going to compute the returns and volatility for the MSCI EUROPE.

# %%
MSCI = pd.read_excel("datas/adjustedMSCIeurope.xlsx")
MSCI.set_index("Ticker Yahoo",inplace=True)
MSCI.drop(["CNH=X","CBK.DE","SW.PA"],axis=0,inplace=True)
MSCI.Weights = MSCI.Weights/100
Tickers = MSCI.index
weights_msci = {ticker:round(MSCI[MSCI.index == ticker].Weights.iloc[0],5) for ticker in Tickers}

# %%
weights_msci
# Out:
# {'NSRGY': 0.05655,
#  'ASML': 0.04093,
#  'ROG.SW': 0.03887,
#  'MC.PA': 0.03403,
#  'NVO': 0.03306,
#  'NVS': 0.03197,
#  'VTI': 0.02543,
#  'SAP': 0.01938,
#  'SIE.DE': 0.01768,
#  'SNY': 0.01744,
#  'OR.PA': 0.01477,
#  'ALV.DE': 0.01477,
#  'SU.PA': 0.01356,
#  'AIR': 0.01296,
#  'ZURN.SW': 0.01211,
#  'AIR.PA': 0.01175,
#  'IBE.MC': 0.01126,
#  'DB': 0.01126,
#  'UBS': 0.0109,
#  'CFR.SW': 0.01066,
#  'BNP.PA': 0.01041,
#  'BMW.DE': 0.00957,
#  'DG.PA': 0.00908,
#  'CS.PA': 0.00896,
#  'EL.PA': 0.00884,
#  'DTG.DE': 0.00872,
#  'ABB': 0.00872,
#  'SAN': 0.00848,
#  'BUD': 0.00823,
#  'RMS.PA': 0.00823,
#  'BAS.DE': 0.00799,
#  'ING': 0.00799,
#  'ENIC': 0.00727,
#  'MUV2.DE': 0.00727,
#  'IFX.DE': 0.00714,
#  'KER.PA': 0.00714,
#  'SAF.PA': 0.00702,
#  'RI.PA': 0.0069,
#  'LONN.SW': 0.00666,
#  'BBVA': 0.00654,
#  'SIKA.SW': 0.00642,
#  'E': 0.0063,
#  'ISP.MI': 0.0063,
#  'EQNR': 0.00605,
#  'BN.PA': 0.00569,
#  'GIVN.SW': 0.00533,
#  'CAP.PA': 0.00521,
#  'AD.AS': 0.00521,
#  'CRH': 0.00521,
#  'DSV.V': 0.00496,
#  'GMAB': 0.00496,
#  '0QKY.IL': 0.00484,
#  'WKL.AS': 0.00484,
#  'VOLCAR-B.ST': 0.00484,
#  'IDEXF': 0.00484,
#  'RWE.DE': 0.00472,
#  'UCG.MI': 0.00472,
#  'RACE': 0.0046,
#  'ENGI.PA': 0.0046,
#  'STM': 0.00448,
#  'VOW3.DE': 0.00448,
#  '6S=F': 0.00436,
#  'NOK': 0.00436,
#  'AMS.MC': 0.004,
#  'HEIA.AS': 0.004,
#  'SAMPO.HE': 0.004,
#  'PDYPY': 0.004,
#  'MRK': 0.004,
#  'SGO.PA': 0.004,
#  'ASSA-B.ST': 0.00388,
#  'EPD': 0.00388,
#  'PHG': 0.00388,
#  'ADDYY': 0.00375,
#  'LR.PA': 0.00375,
#  'REP.MC': 0.00375,
#  'NESTE.HE': 0.00363,
#  'EOAN.DE': 0.00351,
#  'OJ=F': 0.00351,
#  'GLE.PA': 0.00339,
#  'SAND.ST': 0.00339,
#  'TEF': 0.00327,
#  'G.MI': 0.00327,
#  'UPM.HE': 0.00327,
#  'SEB': 0.00315,
#  'LMT': 0.00303,
#  'VNA.DE': 0.00303,
#  'GEBN.SW': 0.00303,
#  'VIE.PA': 0.00291,
#  'KNEBV.HE': 0.00279,
#  'CABK.MC': 0.00279,
#  'KRZ.IR': 0.00266,
#  'SY1.DE': 0.00254,
#  'SGSN.SW': 0.00254,
#  'PUB.PA': 0.00254,
#  'SWED-A.ST': 0.00242,
#  'COLO-B.CO': 0.00242,
#  'SHB-A.ST': 0.00242,
#  'SOON.SW': 0.00242,
#  'MT': 0.00242,
#  'SCMN.SW': 0.0023,
#  'KBC.BR': 0.0023,
#  'HO.PA': 0.0023,
#  'FER.MC': 0.0023,
#  'KNIN.SW': 0.00218,
#  'AKZA.AS': 0.00218,
#  'TEP.PA': 0.00218,
#  'ENBR3.SA': 0.00218,
#  'BAER.SW': 0.00206,
#  'HEN3.DE': 0.00206,
#  'DANSKE.CO': 0.00206,
#  'CARL-B.CO': 0.00206,
#  'CS': 0.00206,
#  'NN': 0.00194,
#  'NZYM-B.CO': 0.00194,
#  'LISN.SW': 0.00194,
#  'HNR1.DE': 0.00194,
#  'MTUM': 0.00194,
#  'QGEN': 0.00194,
#  'FMS': 0.00182,
#  'BNR.DE': 0.00182,
#  'TRN.MI': 0.00182,
#  'AMKBY': 0.00182,
#  'BEI.DE': 0.00182,
#  'KO': 0.00182,
#  'AKRO': 0.00182,
#  'CA.PA': 0.00182,
#  'EBS.VI': 0.00182,
#  'UCBI': 0.0017,
#  'NHYDY': 0.0017,
#  'SRG.MI': 0.0017,
#  'AENA.MC': 0.0017,
#  'SRT3.DE': 0.00157,
#  'P911.DE': 0.00157,
#  'SKG.L': 0.00145,
#  'AEG': 0.00145,
#  'PRY.MI': 0.00145,
#  'ALFAA.MX': 0.00145,
#  'EXO.AS': 0.00145,
#  'GBLC.CN': 0.00145,
#  'HL': 0.00145,
#  'TS': 0.00145,
#  'TRYGBP=X': 0.00145,
#  'RDFN': 0.00145,
#  'FGR.PA': 0.00133,
#  'HEI.DE': 0.00133,
#  'PSTG': 0.00133,
#  'SCA-B.ST': 0.00133,
#  'ALO.PA': 0.00133,
#  'AER': 0.00133,
#  'YAR.OL': 0.00133,
#  'BVI.PA': 0.00133,
#  'OMV.VI': 0.00133,
#  'ELISA.HE': 0.00133,
#  'SCHN.SW': 0.00133,
#  'UMI.BR': 0.00121,
#  '1COV.DE': 0.00121,
#  'TELIA.ST': 0.00121,
#  'UHR.SW': 0.00121,
#  'BEY.L': 0.00121,
#  'SOLB.BR': 0.00121,
#  'RAND.AS': 0.00121,
#  'BALN.SW': 0.00121,
#  'EN.PA': 0.00121,
#  'TEL.OL': 0.00121,
#  'FORTUM.HE': 0.00121,
#  'HZO': 0.00109,
#  'ZAL.DE': 0.00109,
#  'EQT': 0.00109,
#  'SIG': 0.00109,
#  'ECIFY': 0.00109,
#  'RNO.PA': 0.00109,
#  'SKF': 0.00109,
#  'GXE.TO': 0.00109,
#  'VIV.PA': 0.00109,
#  'AC.MX': 0.00109,
#  'ACST': 0.00109,
#  'CDXC': 0.00109,
#  'AGS.BR': 0.00109,
#  'PNDORA.CO': 0.00109,
#  'JMT.LS': 0.00109,
#  'WFDRX': 0.00109,
#  'VER.VI': 0.00097,
#  'MB.MI': 0.00097,
#  'GALP.LS': 0.00097,
#  'ATL.MI': 0.00097,
#  'ELE.MC': 0.00097,
#  'ADEN.SW': 0.00097,
#  'OESX': 0.00097,
#  'SKA-B.ST': 0.00097,
#  'AKE.PA': 0.00097,
#  'ORK.OL': 0.00085,
#  'LI.PA': 0.00085,
#  'ENG.MC': 0.00085,
#  'PST.MI': 0.00085,
#  'BOL.PA': 0.00085,
#  'EMSKF': 0.00085,
#  'LEG': 0.00085,
#  'DIE.BR': 0.00085,
#  'ADP.PA': 0.00085,
#  'GFC.PA': 0.00073,
#  'LHA.DE': 0.00073,
#  'SAGAX': 0.00073,
#  'REC.MI': 0.00073,
#  'SGRE.MC': 0.00073,
#  'SECU-B.ST': 0.00073,
#  'IPN.PA': 0.00073,
#  'IDVA.SG': 0.00073,
#  'NTGY.MC': 0.00073,
#  'EVK.DE': 0.00073,
#  'BIM.PA': 0.00073,
#  'WRTBF': 0.00073,
#  'AC.PA': 0.00073,
#  'GJF.OL': 0.00061,
#  'CLN.SW': 0.00061,
#  'FR.PA': 0.00061,
#  'LBGUF': 0.00061,
#  'RAA.DE': 0.00048,
#  'GRF.MC': 0.00048,
#  'COV.PA': 0.00048,
#  'VOE.VI': 0.00048,
#  'AGNC': 0.00048,
#  'WMB': 0.00048,
#  'MF.PA': 0.00036,
#  'TIT.MI': 0.00036,
#  'KGX.DE': 0.00036,
#  'UPS': 0.00036,
#  'VSBY.CN': 0.00036,
#  'PROX.BR': 0.00024}

# %%
returns_msci = {}
vol_msci = {}
tri = 1
year = 0
for i in list(periods.keys())[1:]:
    rends_period = rends_msci.loc[periods[i].index[0]:periods[i].index[-1]]
    rends_period = rends_period[weights_msci.keys()]
    npw = np.array(list(weights_msci.values()))
    returns_msci[f"Q{tri%4+1}-{2005+year}"] = pf.portfolio_rend(npw,rends_period)
    vol_msci[f"Q{tri%4+1}-{2005+year}"] = pf.portfolio_vol(npw,rends_period.cov())
    tri += 1
    if tri%4 == 0:
        year += 1

# %% [markdown]
# # 6. Analysis

# %% [markdown]
# Now we are doing some analysis to compare the MSCI and our portfolio. We will only focus on the **10-years period** from **Q1-2013** to **Q4-2022**.

# %%
size = 40
R_P = np.array(list(returns_tc.values())[-size:])
V_P = np.array(list(vol_tc.values())[-size:])
R_M = np.array(list(returns_msci.values())[-size:])
V_M = np.array(list(vol_msci.values())[-size:])
diff_rends = R_P - R_M
diff_vol = V_P - V_M

# %% [markdown]
# ## Returns

# %%
# Percentage of negative quarterly returns
print(f"Percentage of positive quarterly returns for the portfolio: {round((R_P>= 0).sum()/(R_P.shape[0])*100,2)}% ({(R_P>= 0).sum()} quarters).")
print(f"Percentage of positive quarterly returns for the MSCI: {round((R_M>= 0).sum()/(R_M.shape[0])*100,2)}% ({(R_M>= 0).sum()} quarters).")
# Out:
# Percentage of positive quarterly returns for the portfolio: 57.5% (23 quarters).
# Percentage of positive quarterly returns for the MSCI: 70.0% (28 quarters).

# %% [markdown]
# Our porfolio has **57.5%** of the time positive returns compared to **70%** of the time for the MSCI EUROPE (it's a difference of 5 quarters).

# %%
# Max Drawdown
print(f"Max Drawdown for the portfolio: {round(R_P.min()*100,2)}%")
print(f"Max Drawdown for the MSCI: {round(R_M.min()*100,2)}%")
# Out:
# Max Drawdown for the portfolio: -36.3%
# Max Drawdown for the MSCI: -23.79%

# %% [markdown]
# We also observed the maximum drawdown of our portfolio and the MSCI Europe. We found a drawdown of **-36.3%** (annualized) during Q2-2015 and **-23.79%** for the MSCI (annualized) during Q1-2021.

# %%
# Highest return
print(f"Highest return for the portfolio: {round(R_P.max()*100,2)}%")
print(f"Highest return for the MSCI: {round(R_M.max()*100,2)}%")
# Out:
# Highest return for the portfolio: 101.92%
# Highest return for the MSCI: 110.42%

# %% [markdown]
# We also observed the highest return of our portfolio and the MSCI Europe. We found a return of **101.92%** (annualized) during Q1-2013 and **110.42%** for the MSCI (annualized) during Q1-2015.

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
size = 40
width = 0.25
br1  = np.arange(size)
br2 = [x + width for x in br1]
ax.bar(br1, list(returns_tc.values())[-size:], color = 'black', width = width,label="Portfolio")
ax.bar(br2, list(returns_msci.values())[-size:], color = 'gray', width = width,label="MSCI")
plt.xlabel('Quarters', fontweight ='bold', fontsize = 15)
plt.ylabel('Annualized returns', fontweight ='bold', fontsize = 15)
plt.title("Comparison of the portfolio and MSCI returns", fontweight ='bold', fontsize = 15)
plt.xticks([r + width/2 for r in range(size)],list(returns_msci.keys())[-size:],rotation=90)
plt.legend(fontsize=15)
plt.show()

# %%
# (Not efficient) Average annualized return
print(f"Average annualized return for the portfolio: {round(np.array(list(returns_tc.values())).mean()*100,2)}%")
print(f"Average annualized return for the MSCI: {round(np.array(list(returns_msci.values())).mean()*100,2)}%")
# Out:
# Average annualized return for the portfolio: 6.47%
# Average annualized return for the MSCI: 14.86%

# %% [markdown]
# ## Volatility

# %%
# Average annualized volatility
print(f"Average annualized volatility for the portfolio: {round(np.array(list(vol_tc.values())).mean()*100,2)}%")
print(f"Average annualized volatility for the MSCI: {round(np.array(list(vol_msci.values())).mean()*100,2)}%")
# Out:
# Average annualized volatility for the portfolio: 10.34%
# Average annualized volatility for the MSCI: 15.16%

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
size = 40
width = 0.25
br1  = np.arange(size)
ax.bar(br1,diff_rends[-size:], color = 'black', width = width,label="$R_{portfolio}-R_{msci}$")
plt.xlabel('Quarters', fontweight ='bold', fontsize = 15)
plt.ylabel('Annualized returns', fontweight ='bold', fontsize = 15)
plt.title("Differences between the portfolio and MSCI returns", fontweight ='bold', fontsize = 15)
plt.xticks([r for r in range(size)],list(returns_msci.keys())[-size:],rotation=90)
plt.legend(fontsize=15)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
size = 40
width = 0.25
br1  = np.arange(size)
br2 = [x + width for x in br1]
ax.bar(br1, list(vol_tc.values())[-size:], color = 'black', width = width,label="Portfolio")
ax.bar(br2, list(vol_msci.values())[-size:], color = 'gray', width = width,label="MSCI")
plt.xlabel('Quarters', fontweight ='bold', fontsize = 15)
plt.ylabel('Annualized volatility', fontweight ='bold', fontsize = 15)
plt.title("Comparison of the portfolio and MSCI volatilities", fontweight ='bold', fontsize = 15)
plt.xticks([r + width/2 for r in range(size)],list(vol_msci.keys())[-size:],rotation=90)
plt.legend(fontsize=15)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
size = 40
width = 0.25
br1  = np.arange(size)
ax.bar(br1,-diff_vol[-size:], color = 'black', width = width,label="$\sigma_{msci}-\sigma_{portfolio}$")
plt.xlabel('Quarters', fontweight ='bold', fontsize = 15)
plt.ylabel('Annualized returns', fontweight ='bold', fontsize = 15)
plt.title("Differences between the portfolio and the MSCI volatilities", fontweight ='bold', fontsize = 15)
plt.xticks([r for r in range(size)],list(returns_msci.keys())[-size:],rotation=90)
plt.legend(fontsize=15)
plt.show()

# %%
(-diff_vol[-40:] < 0).sum()/40
# Out:
# 0.4

# %%
print(f"Gap between volatilities where the MSCI vol is lower than the Portfolio vol: {round(-diff_vol[-40:][(-diff_vol[-40:] < 0)].mean(),3)}")
print(f"Gap between volatilities where the MSCI vol is lower than the Portfolio vol: {round(-diff_vol[-40:][(-diff_vol[-40:] >= 0)].mean(),3)}")
# Out:
# Gap between volatilities where the MSCI vol is lower than the Portfolio vol: -0.033
# Gap between volatilities where the MSCI vol is lower than the Portfolio vol: 0.064

# %% [markdown]
# We saw a big difference between volatilities. On a 10 years period the volatility of the MSCI is **40%** of the time lower than the portofolio volatility. But in these cases the gap is only **0.033%** in average. If we take only the cases where the MSCI volatility is greater than the porfolio volatility, we saw that the gap is now **0.064** in average.
